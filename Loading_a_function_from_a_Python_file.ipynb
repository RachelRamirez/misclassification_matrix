# %% [markdown]
# <a href="https://colab.research.google.com/github/RachelRamirez/misclassification_matrix/blob/main/Loading_a_function_from_a_Python_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We'll start by writing a `.py` file which we'll import.

# %%
# %%writefile example.py
def f():
  print ('This is a function defined in a Python source file.')
# Out:
# Writing example.py

# %%
# %%writefile ImportLibraries_DefineFunctions.py
import time
time.localtime(time.time())
#For Reproducibility
import numpy as np
# np.random.seed(1337)  # for reproducibility

import tensorflow as tf
# tf.random.set_seed(33)

import random as python_random
# python_random.seed(4)

# https://www.tensorflow.org/api_docs/python/tf/keras/utils/set_random_seed
seed = 342
tf.keras.utils.set_random_seed(seed) #Possibly use next iteration if the above doesn't work   #This makes everything VERY DETERMINISTIC


# Running more than once causes variation.  try adding this:
# Set seed value
seed_value = 56
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

print("TF version: " , tf.__version__ )
print("Keras version: " , tf.keras.__version__ )


 

# from __future__ import print_function  #do i still need this?
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam, RMSprop
from keras.utils import np_utils
import keras.backend as K
from itertools import product
import functools
from functools import partial
from time import ctime
from time import sleep
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
from sklearn.metrics import confusion_matrix, classification_report   #CLASSIFICATION REPORT IS FOR F1 SCORE AND BREAKOUT OF AL CATEGORIES ACCURACYS
from  sklearn.utils import shuffle
from sklearn.metrics import f1_score
 
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)

print("Finished Loading Libraries")


batch_size = 256 

# I originally had it very  high batch size to reduce the variation in the data each batch and hope 
# it makes the model training more nearly identical which it did, then i bring it back down to something reasonable to get better results training the NN

nb_classes = 10

# the data, shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()


X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
# print(X_train.shape[0], 'train samples')
# print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

#Create a Validation Set
X_val = X_test[:7500]   #take the first 7500 for validation
Y_val = Y_test[:7500]   #Take the first 7500 for validation
y_val = y_test[:7500]

X_test = X_test[7500:]  #Keep the last 2500 for test/holdout
Y_test = Y_test[7500:]  #Keep the last 2500 for test/holdout
y_test = y_test[7500:]

print(X_train.shape[0], 'train samples')
print(X_val.shape[0], 'validation samples')
print(X_test.shape[0], 'test samples')

#Are the sets relatively balanced? Yes each category is between 8% and 11% per category
print('Train', Y_train.sum(axis=0)/X_train.shape[0])
print('Train # of 9s', Y_train.sum(axis=0)[9])
print('Train # of 4s', Y_train.sum(axis=0)[4])

print('Val', Y_val.sum(axis=0)/X_val.shape[0])
print('Val # of 9s', Y_val.sum(axis=0)[9])
print('Val # of 4s', Y_val.sum(axis=0)[4])

print('Test', Y_test.sum(axis=0)/X_test.shape[0])
print('Test  # of 9s', Y_test.sum(axis=0)[9])
print('Test  # of 4s', Y_test.sum(axis=0)[4])

#@title
class WeightedCategoricalCrossentropy(tf.keras.losses.CategoricalCrossentropy):

  def __init__(self, cost_mat, name='weighted_categorical_crossentropy', **kwargs):

    cost_mat = np.array(cost_mat)   
    ## when loading from config, self.cost_mat returns as a list, rather than an numpy array. 
    ## Adding the above line fixes this issue, enabling .ndim to call sucessfully. 
    ## However, this is probably not the best implementation
    assert(cost_mat.ndim == 2)
    assert(cost_mat.shape[0] == cost_mat.shape[1])
    super().__init__(name=name, **kwargs)
    self.cost_mat = K.cast_to_floatx(cost_mat)

  def __call__(self, y_true, y_pred, sample_weight=None):
    assert sample_weight is None, "should only be derived from the cost matrix"  
    return super().__call__(
        y_true=y_true, 
        y_pred=y_pred, 
        sample_weight=get_sample_weights(y_true, y_pred, self.cost_mat),
    )


  def get_config(self):
    config = super().get_config().copy()
    # Calling .update on the line above, during assignment, causes an error with config becoming None-type.
    config.update({'cost_mat': (self.cost_mat)})
    return config

  @classmethod
  def from_config(cls, config):
    # something goes wrong here and changes self.cost_mat to a list variable.
    # See above for temporary fix
    return cls(**config)

def get_sample_weights(y_true, y_pred, cost_m):
    num_classes = len(cost_m)

    y_pred.shape.assert_has_rank(2)
    assert(y_pred.shape[1] == num_classes)
    y_pred.shape.assert_is_compatible_with(y_true.shape)

    y_pred = K.one_hot(K.argmax(y_pred), num_classes)

    y_true_nk1 = K.expand_dims(y_true, 2)
    y_pred_n1k = K.expand_dims(y_pred, 1)
    cost_m_1kk = K.expand_dims(cost_m, 0)

    sample_weights_nkk = cost_m_1kk * y_true_nk1 * y_pred_n1k
    sample_weights_n = K.sum(sample_weights_nkk, axis=[1, 2])

    return sample_weights_n


# Register the loss in the Keras namespace to enable loading of the custom object.
tf.keras.losses.WeightedCategoricalCrossentropy = WeightedCategoricalCrossentropy
 
#@title
def plot_model_history(model_history, nb_epoch, cm3): 
  # Parameters
  # ----------
  # model_history : keras.callbacks.History
  #     The history object returned by the fit() method of the model.
  # cm3 : 10x10 dataframe 
  #      10x10 dataframe of confusion matrix from predicted X_val categories
  # nb_epoch = restored_weights : int
  #     The epoch at which the weights were restored.
  # tot_epochs : int
  #     Calculated Total number of epochs for which the model was trained.
  
   
  tot_epochs = max(model_history.epoch)+1  #if the total epochs ran is 28, it'll show up as 27 in the epoch object so we must add 1
  print("Total Epochs: ", tot_epochs)

  #if tot_epochs is the total number of epochs ran then early stop did not happen, and we need not minus patience
  if tot_epochs == nb_epoch:
    restored_weights = tot_epochs
  else:
    restored_weights  = tot_epochs-patience   #when using restore-best-weights and patience, it'll restore the best weights back
  print("Restored weights at ", restored_weights, "Patience used: ", patience)

  fig = plt.figure(figsize=(20, 10)) # I don't think this works for some reason
  fig, ax = plt.subplots(1,3)
  ax[0].plot(range(1,tot_epochs+1), model_history.history['categorical_accuracy'], color='blue',             label='Training')
  ax[0].plot(range(1,tot_epochs+1), model_history.history['val_categorical_accuracy'] , color='orange',             label='Validation')
  ax[0].scatter((restored_weights), model_history.history['val_categorical_accuracy'][restored_weights-1] , color='orange')
  ax[0].scatter(restored_weights, model_history.history['categorical_accuracy'][restored_weights-1], color='blue')
  ax[0].annotate(text=str(restored_weights),  xy=(restored_weights, model_history.history['val_categorical_accuracy'][restored_weights-1]),
                  textcoords="offset points", xytext=(0,10), ha='center', color='black')
  ax[0].legend()
  ax[0].set_title('Training and Validation Accuracy')

  ax[1].plot(range(1,tot_epochs+1), model_history.history['loss'], color= 'blue', label='Training')
  ax[1].plot(range(1,tot_epochs+1), model_history.history['val_loss'], color='orange', label='Validation')
  ax[1].scatter(restored_weights, model_history.history['loss'][restored_weights-1], color='blue')
  ax[1].scatter((restored_weights), model_history.history['val_loss'][restored_weights-1] , color='orange')
  ax[1].annotate(text=str(restored_weights),  xy=(restored_weights, model_history.history['val_loss'][restored_weights-1]),
                  textcoords="offset points", xytext=(0,10), ha='center')
  ax[1].legend()
  ax[1].set_title('Training and Validation Loss')


  cm3_wodiag = cm3*(np.ones((10,10)) - np.eye(10))

  ax[2] = sns.heatmap(cm3_wodiag, annot=True, annot_kws={"size": 7},  fmt='g', cmap=sns.cm.rocket_r) # font size
  ax[2].set_xlabel('Predicted Class')
  ax[2].set_ylabel('True Class')
  ax[2].set_title('# of misclassifications of 9 as 4 is '+str(cm3[4][9]))
  cbar = ax[2].collections[0].colorbar
  cbar.remove() # Just takes up valuable room and is worthless


  plt.gcf().set_size_inches(15, 5)  # this works 
  # plt.gcf().suptitle(f"Lambda Value {lambda_val} for {nb_epoch} Epochs and Patience {patience} " )


  #@title
def create_model(): #Removed cost-matrix which is called up in the Compile Function and passed to the weighted-loss function
  model = Sequential()
  model.add(Dense(40, input_shape=(784,), kernel_initializer=tf.keras.initializers.glorot_uniform(seed=42)))
  model.add(Activation('relu'))
  model.add(Dropout(0.2))
  model.add(Dense(40, kernel_initializer=tf.keras.initializers.glorot_uniform(seed=42)))
  model.add(Activation('relu'))
  model.add(Dropout(0.2))
  model.add(Dense(10,kernel_initializer=tf.keras.initializers.glorot_uniform(seed=42)))
  model.add(Activation('softmax'))
  return model  #I removed Compile



  #@title
def log_confusion_matrix( epoch, logs):
  # Use the model to predict the values from the validation dataset.
  y_prediction = model.predict(X_val, verbose=0)     #I call it y_prediction3 because I just want to make sure this is  updated within and not interfering with the other prediction below
  y_prediction  = np.argmax(y_prediction, axis=1)

  #Create confusion matrix 
  cm = confusion_matrix(y_val, y_prediction)
  cm_array = np.asarray(cm)  #Indiv CM as array for storing
  logs['9T_4P'] = cm[9,4]
  logs['4T_9P'] = cm[4,9]

  logs['0T_Acc'] = cm[0,0]/np.sum(cm[0])
  logs['1T_Acc'] = cm[1,1]/np.sum(cm[1])
  logs['2T_Acc'] = cm[2,2]/np.sum(cm[2])
  logs['3T_Acc'] = cm[3,3]/np.sum(cm[3])
  logs['4T_Acc'] = cm[4,4]/np.sum(cm[4])
  logs['5T_Acc'] = cm[5,5]/np.sum(cm[5])
  logs['6T_Acc'] = cm[6,6]/np.sum(cm[6])
  logs['7T_Acc'] = cm[7,7]/np.sum(cm[7])
  logs['8T_Acc'] = cm[8,8]/np.sum(cm[8])
  logs['9T_Acc'] = cm[9,9]/np.sum(cm[9])


  logs['cm_per_epoch'] = cm_array.reshape((1,100))

#@title
def log_classification_report( epoch, logs):
  # Use the model to predict the values from the validation dataset.
    y_prediction = model.predict(X_val, verbose=0)     #I call it y_prediction3 because I just want to make sure this is  updated within and not interfering with the other prediction below
    y_prediction  = np.argmax(y_prediction, axis=1)

    #Create confusion matrix 
    cr = classification_report(y_val, y_prediction)
    # print(cr)
    logs['cr_per_epoch'] = cr 


    #@title
def log_f1_score( epoch, logs):
  # Use the model to predict the values from the validation dataset.
    y_prediction = model.predict(X_val, verbose=0)     #I call it y_prediction3 because I just want to make sure this is  updated within and not interfering with the other prediction below
    y_prediction  = np.argmax(y_prediction, axis=1)


    logs["f1_micro"] = f1_score(y_val, y_prediction, average='micro')
    logs["f1_macro"] = f1_score(y_val, y_prediction, average='macro')
    logs["f1_weighted"] = f1_score(y_val, y_prediction, average='weighted')
    logs["f1_notweighted"] = f1_score(y_val, y_prediction, average=None)


#@title
def return_cm(model):
  y_prediction = model.predict(X_val, verbose=0)
  y_prediction  = np.argmax(y_prediction, axis=1)
  # Y_prediction = np_utils.to_categorical(y_prediction, nb_classes)

  cm3 = confusion_matrix(y_val, y_prediction)
  cm3 = pd.DataFrame(cm3, range(10),range(10))
  return cm3

  # # plt.figure(figsize = (4,4))
  # # cm3
  # sns.heatmap(cm3, annot=True, annot_kws={"size": 7},  fmt='g') # font size
  # plt.show()
  # # cm_using_weighted_new = cm3
 #@title

def return_cr(model):
  y_prediction = model.predict(X_val, verbose=0)
  y_prediction  = np.argmax(y_prediction, axis=1)
  # Y_prediction = np_utils.to_categorical(y_prediction, nb_classes)

  cr = classification_report(y_val, y_prediction)
  print(cr)
  return cr


def return_f1score(model):
  # sklearn.metrics.f1_score(y_true, y_pred, *, labels=None, pos_label=1, average='binary', sample_weight=None, zero_division='warn')[source] 
  y_prediction = model.predict(X_val, verbose=0)
  y_prediction  = np.argmax(y_prediction, axis=1)
  # Y_prediction = np_utils.to_categorical(y_prediction, nb_classes)

  f1_notweighted = f1_score(y_val, y_prediction, average=None)
  print(f1_notweighted)
  f1_micro = f1_score(y_val, y_prediction, average='micro')
  f1_macro = f1_score(y_val, y_prediction, average='macro')
  f1_weighted = f1_score(y_val, y_prediction, average='weighted')
  # print("Micro: ", f1_micro, "Macro: ", f1_macro, "Weighted: ", f1_weighted)
  print("Micro: {:.5f} Macro: {:.5f} Weighted: {:.5f}".format(f1_micro, f1_macro, f1_weighted))
  # return f1

## ----------------------------------------------------------------------------------------------
## Tried to create a Callback to call the Classifcatinreport ever 5 epochs, but it doesnt work 
## because it cant see the model.  ZGoing back to trying to define the function to only be called every 5th epoch


# class cr_callback(tf.keras.callbacks.Callback):

#     def on_epoch_end(self, epoch, log=None):

#         if epoch % 5 == 0:  # <- add additional condition here
#             self._do_the_stuff()
            
            
#     def _do_the_stuff(self, model):
#         print('Do the stuff')
#         y_prediction = model.predict(X_val, verbose=0)
#         y_prediction  = np.argmax(y_prediction, axis=1)
#         # Y_prediction = np_utils.to_categorical(y_prediction, nb_classes)
#         cr = classification_report(y_val, y_prediction)
#         logs['cr'] = cr

#           # return cr
        
#     # def on_training_end(self, logs=None):
#     #     self._do_the_stuff()



## Saw this example ono Kaggle, but couldn't get it to work, it does give me an idea(if epoch==0)

# from sklearn.metrics import accuracy_score
# class every10epochCallback(tf.keras.callbacks.Callback):
#     def __init__(self, X_val, Y_val):
#         super().__init__()
#         self.X = X_val
#         self.y = Y_val.argmax(axis=1)
#     def on_epoch_begin(self, epoch, logs=None):
#         if epoch == 0:
#             return
#         if epoch%10==0:
#             pred = (model.predict(self.X))
#             print('epoch: ',epoch,'  ,Accuracy:  ',accuracy_score(self.y,pred.argmax(axis=1)),' ')

# model.fit(X_train, Y_train,batch_size=batch_size,epochs=10,verbose=0,  validation_data=(X_val, Y_val), shuffle=True, use_multiprocessing=True, 
#           callbacks=[every10epochCallback(X_val,Y_val)])
# Out:
# Writing ImportLibraries_DefineFunctions.py

# %%
#@title
# Bring the file into the local Python environment.
execfile('ImportLibraries_DefineFunctions.py')

# Call the function defined in the file.
# f()
# Out:
# TF version:  2.12.0
# Keras version:  2.12.0
# Finished Loading Libraries
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# 60000 train samples
# 7500 validation samples
# 2500 test samples
# Train [0.09871667 0.11236667 0.0993     0.10218333 0.09736667 0.09035
#  0.09863333 0.10441667 0.09751666 0.09915   ]
# Train # of 9s 5949.0
# Train # of 4s 5842.0
# Val [0.09586667 0.1132     0.10453334 0.10066666 0.09986667 0.09013333
#  0.09413333 0.1016     0.09746667 0.10253333]
# Val # of 9s 769.0
# Val # of 4s 749.0
# Test [0.1044 0.1144 0.0992 0.102  0.0932 0.0864 0.1008 0.1064 0.0972 0.096 ]
# Test  # of 9s 240.0
# Test  # of 4s 233.0

# %%
#@title
# #As of 4/18 I am changing this code to save weights initially after five epochs using lambdavalue=1 initially

# rms = RMSprop()  #https://keras.io/api/optimizers/rmsprop/ #default learning_rate=0.001
sgd = SGD(learning_rate=0.1)

patience = 0


# SET THE IITIAL LAMBDA VALUE! 
cost_matrix = np.ones((10,10))
lambda_val = 1

Truth=9
Predicted=4
cost_matrix[Truth, Predicted] = lambda_val


# # Define the per-epoch callback.
cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix, )
# cr_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_classification_report, )
# es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, verbose=1, restore_best_weights = True)





# ## Examples from TDS
# from tensorflow.keras.callbacks import LambdaCallback
# epoch_callback = LambdaCallback(
#     on_epoch_begin=lambda epoch,logs: print('Starting Epoch {}!'.format(epoch+1))
# )
# batch_loss_callback = LambdaCallback(
#     on_batch_end=lambda batch,logs: print('\n After batch {}, the loss is {:7.2f}.'.format(batch, logs['loss']))
# )
# train_finish_callback = LambdaCallback(
#     on_train_end=lambda logs: print('Training finished!')
# )

# # Lambda function using if else & else if
# min = lambda a, b, c : f"{a} is smaller" if(a < b & b < c) \
#      else f"{b} is smaller"  if (b < c) else f"{c} is smaller" 
# print(min(40, 30, 10))

epoch_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end = lambda epoch,logs: 
                                                   print(' Epoch {} modulus 5 is {}!'.format(epoch+1, (epoch+1)%5))  )

# cr_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end= lambda epoch, logs:
# #                                                log_classification_report(epoch, logs) if(epoch+1)%5==0 else print(" ") )
#                                               #  return_cr if(epoch+1)%5==0 else print(" ") )


f1_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_f1_score)


model = create_model()

# save the model weights
model.save_weights('initial_0epochs.h5')



model.compile(loss=WeightedCategoricalCrossentropy(cost_matrix), optimizer=sgd,  metrics='categorical_accuracy',)

model_history = model.fit(X_train, Y_train,  batch_size=batch_size, epochs=10, verbose=2,
        validation_data=(X_val, Y_val), shuffle=True, use_multiprocessing=True, callbacks = [ cm_callback, f1_callback])

model.save_weights('initial_10epochs.h5')

# save the model weights
# model.save_weights('initial_150epochs.h5')

 
cr = return_cr(model)
# Out:
# Epoch 1/10
# 235/235 - 5s - loss: 0.9456 - categorical_accuracy: 0.6950 - val_loss: 0.3900 - val_categorical_accuracy: 0.8893 - 9T_4P: 40.0000 - 4T_9P: 43.0000 - 0T_Acc: 0.9624 - 1T_Acc: 0.9670 - 2T_Acc: 0.8546 - 3T_Acc: 0.8596 - 4T_Acc: 0.9092 - 5T_Acc: 0.8284 - 6T_Acc: 0.9263 - 7T_Acc: 0.8570 - 8T_Acc: 0.8591 - 9T_Acc: 0.8609 - cm_per_epoch: 75.0000 - f1_micro: 0.8893 - f1_macro: 0.8882 - f1_weighted: 0.8891 - f1_notweighted: 0.8882 - 5s/epoch - 23ms/step
# Epoch 2/10
# 235/235 - 1s - loss: 0.4861 - categorical_accuracy: 0.8544 - val_loss: 0.3128 - val_categorical_accuracy: 0.9083 - 9T_4P: 32.0000 - 4T_9P: 35.0000 - 0T_Acc: 0.9750 - 1T_Acc: 0.9776 - 2T_Acc: 0.8852 - 3T_Acc: 0.8755 - 4T_Acc: 0.9199 - 5T_Acc: 0.8698 - 6T_Acc: 0.9348 - 7T_Acc: 0.8976 - 8T_Acc: 0.8550 - 9T_Acc: 0.8843 - cm_per_epoch: 75.0000 - f1_micro: 0.9083 - f1_macro: 0.9073 - f1_weighted: 0.9079 - f1_notweighted: 0.9073 - 1s/epoch - 6ms/step
# Epoch 3/10
# 235/235 - 1s - loss: 0.4074 - categorical_accuracy: 0.8777 - val_loss: 0.2661 - val_categorical_accuracy: 0.9207 - 9T_4P: 34.0000 - 4T_9P: 20.0000 - 0T_Acc: 0.9750 - 1T_Acc: 0.9753 - 2T_Acc: 0.9107 - 3T_Acc: 0.9152 - 4T_Acc: 0.9399 - 5T_Acc: 0.8876 - 6T_Acc: 0.9448 - 7T_Acc: 0.9029 - 8T_Acc: 0.8687 - 9T_Acc: 0.8804 - cm_per_epoch: 75.0000 - f1_micro: 0.9207 - f1_macro: 0.9197 - f1_weighted: 0.9204 - f1_notweighted: 0.9197 - 1s/epoch - 6ms/step
# Epoch 4/10
# 235/235 - 1s - loss: 0.3624 - categorical_accuracy: 0.8937 - val_loss: 0.2397 - val_categorical_accuracy: 0.9272 - 9T_4P: 27.0000 - 4T_9P: 27.0000 - 0T_Acc: 0.9764 - 1T_Acc: 0.9800 - 2T_Acc: 0.9120 - 3T_Acc: 0.9113 - 4T_Acc: 0.9319 - 5T_Acc: 0.9053 - 6T_Acc: 0.9433 - 7T_Acc: 0.9160 - 8T_Acc: 0.8974 - 9T_Acc: 0.8934 - cm_per_epoch: 75.0000 - f1_micro: 0.9272 - f1_macro: 0.9265 - f1_weighted: 0.9270 - f1_notweighted: 0.9265 - 1s/epoch - 6ms/step
# Epoch 5/10
# 235/235 - 1s - loss: 0.3262 - categorical_accuracy: 0.9033 - val_loss: 0.2211 - val_categorical_accuracy: 0.9325 - 9T_4P: 34.0000 - 4T_9P: 16.0000 - 0T_Acc: 0.9791 - 1T_Acc: 0.9800 - 2T_Acc: 0.9349 - 3T_Acc: 0.9311 - 4T_Acc: 0.9439 - 5T_Acc: 0.9024 - 6T_Acc: 0.9533 - 7T_Acc: 0.8950 - 8T_Acc: 0.9124 - 9T_Acc: 0.8882 - cm_per_epoch: 75.0000 - f1_micro: 0.9325 - f1_macro: 0.9320 - f1_weighted: 0.9323 - f1_notweighted: 0.9320 - 1s/epoch - 6ms/step
# Epoch 6/10
# 235/235 - 1s - loss: 0.3052 - categorical_accuracy: 0.9103 - val_loss: 0.2029 - val_categorical_accuracy: 0.9389 - 9T_4P: 14.0000 - 4T_9P: 33.0000 - 0T_Acc: 0.9819 - 1T_Acc: 0.9812 - 2T_Acc: 0.9401 - 3T_Acc: 0.9351 - 4T_Acc: 0.9266 - 5T_Acc: 0.9083 - 6T_Acc: 0.9419 - 7T_Acc: 0.9213 - 8T_Acc: 0.9248 - 9T_Acc: 0.9220 - cm_per_epoch: 75.0000 - f1_micro: 0.9389 - f1_macro: 0.9385 - f1_weighted: 0.9388 - f1_notweighted: 0.9385 - 1s/epoch - 6ms/step
# Epoch 7/10
# 235/235 - 2s - loss: 0.2922 - categorical_accuracy: 0.9153 - val_loss: 0.1946 - val_categorical_accuracy: 0.9409 - 9T_4P: 10.0000 - 4T_9P: 27.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9823 - 2T_Acc: 0.9247 - 3T_Acc: 0.9391 - 4T_Acc: 0.9413 - 5T_Acc: 0.9157 - 6T_Acc: 0.9433 - 7T_Acc: 0.9094 - 8T_Acc: 0.9261 - 9T_Acc: 0.9376 - cm_per_epoch: 75.0000 - f1_micro: 0.9409 - f1_macro: 0.9405 - f1_weighted: 0.9409 - f1_notweighted: 0.9405 - 2s/epoch - 7ms/step
# Epoch 8/10
# 235/235 - 1s - loss: 0.2732 - categorical_accuracy: 0.9203 - val_loss: 0.1828 - val_categorical_accuracy: 0.9441 - 9T_4P: 19.0000 - 4T_9P: 19.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9812 - 2T_Acc: 0.9439 - 3T_Acc: 0.9404 - 4T_Acc: 0.9493 - 5T_Acc: 0.9112 - 6T_Acc: 0.9476 - 7T_Acc: 0.9370 - 8T_Acc: 0.9275 - 9T_Acc: 0.9142 - cm_per_epoch: 75.0000 - f1_micro: 0.9441 - f1_macro: 0.9436 - f1_weighted: 0.9440 - f1_notweighted: 0.9436 - 1s/epoch - 6ms/step
# Epoch 9/10
# 235/235 - 1s - loss: 0.2634 - categorical_accuracy: 0.9226 - val_loss: 0.1769 - val_categorical_accuracy: 0.9464 - 9T_4P: 17.0000 - 4T_9P: 19.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9812 - 2T_Acc: 0.9401 - 3T_Acc: 0.9364 - 4T_Acc: 0.9493 - 5T_Acc: 0.9157 - 6T_Acc: 0.9575 - 7T_Acc: 0.9304 - 8T_Acc: 0.9439 - 9T_Acc: 0.9220 - cm_per_epoch: 75.0000 - f1_micro: 0.9464 - f1_macro: 0.9460 - f1_weighted: 0.9463 - f1_notweighted: 0.9460 - 1s/epoch - 6ms/step
# Epoch 10/10
# 235/235 - 1s - loss: 0.2517 - categorical_accuracy: 0.9251 - val_loss: 0.1668 - val_categorical_accuracy: 0.9499 - 9T_4P: 13.0000 - 4T_9P: 22.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9812 - 2T_Acc: 0.9452 - 3T_Acc: 0.9404 - 4T_Acc: 0.9453 - 5T_Acc: 0.9453 - 6T_Acc: 0.9518 - 7T_Acc: 0.9304 - 8T_Acc: 0.9412 - 9T_Acc: 0.9311 - cm_per_epoch: 75.0000 - f1_micro: 0.9499 - f1_macro: 0.9496 - f1_weighted: 0.9498 - f1_notweighted: 0.9496 - 1s/epoch - 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       719
#            1       0.97      0.98      0.98       849
#            2       0.95      0.95      0.95       784
#            3       0.95      0.94      0.95       755
#            4       0.95      0.95      0.95       749
#            5       0.95      0.95      0.95       676
#            6       0.95      0.95      0.95       706
#            7       0.96      0.93      0.94       762
#            8       0.94      0.94      0.94       731
#            9       0.93      0.93      0.93       769
#
#     accuracy                           0.95      7500
#    macro avg       0.95      0.95      0.95      7500
# weighted avg       0.95      0.95      0.95      7500

# %%
# how can i dig into the Classification Report
model_history.history
# Out:
# {'loss': [0.9456429481506348,
#   0.4860854148864746,
#   0.40739163756370544,
#   0.3623688519001007,
#   0.3261603116989136,
#   0.30523985624313354,
#   0.2922259569168091,
#   0.27316585183143616,
#   0.2633598744869232,
#   0.251666784286499],
#  'categorical_accuracy': [0.6949666738510132,
#   0.854449987411499,
#   0.8777333498001099,
#   0.8937000036239624,
#   0.9033166766166687,
#   0.9102500081062317,
#   0.9152666926383972,
#   0.9203166961669922,
#   0.9226499795913696,
#   0.9251333475112915],
#  'val_loss': [0.39003026485443115,
#   0.31284916400909424,
#   0.2661421000957489,
#   0.2397366762161255,
#   0.221100315451622,
#   0.20287352800369263,
#   0.19456474483013153,
#   0.1828291118144989,
#   0.1769355982542038,
#   0.16680926084518433],
#  'val_categorical_accuracy': [0.8893333077430725,
#   0.9082666635513306,
#   0.9206666946411133,
#   0.9272000193595886,
#   0.932533323764801,
#   0.9389333128929138,
#   0.940933346748352,
#   0.9441333413124084,
#   0.946399986743927,
#   0.9498666524887085],
#  '9T_4P': [40, 32, 34, 27, 34, 14, 10, 19, 17, 13],
#  '4T_9P': [43, 35, 20, 27, 16, 33, 27, 19, 19, 22],
#  '0T_Acc': [0.9624478442280946,
#   0.9749652294853964,
#   0.9749652294853964,
#   0.9763560500695411,
#   0.9791376912378303,
#   0.9819193324061196,
#   0.9847009735744089,
#   0.9833101529902643,
#   0.9833101529902643,
#   0.9847009735744089],
#  '1T_Acc': [0.967020023557126,
#   0.9776207302709069,
#   0.9752650176678446,
#   0.9799764428739693,
#   0.9799764428739693,
#   0.9811542991755006,
#   0.9823321554770318,
#   0.9811542991755006,
#   0.9811542991755006,
#   0.9811542991755006],
#  '2T_Acc': [0.8545918367346939,
#   0.8852040816326531,
#   0.9107142857142857,
#   0.9119897959183674,
#   0.9349489795918368,
#   0.9400510204081632,
#   0.9247448979591837,
#   0.9438775510204082,
#   0.9400510204081632,
#   0.9451530612244898],
#  '3T_Acc': [0.8596026490066225,
#   0.8754966887417218,
#   0.9152317880794701,
#   0.9112582781456954,
#   0.9311258278145695,
#   0.9350993377483444,
#   0.9390728476821192,
#   0.9403973509933775,
#   0.9364238410596026,
#   0.9403973509933775],
#  '4T_Acc': [0.9092122830440588,
#   0.9198931909212283,
#   0.9399198931909212,
#   0.931909212283044,
#   0.9439252336448598,
#   0.9265687583444593,
#   0.9412550066755674,
#   0.9492656875834445,
#   0.9492656875834445,
#   0.945260347129506],
#  '5T_Acc': [0.8284023668639053,
#   0.8698224852071006,
#   0.8875739644970414,
#   0.9053254437869822,
#   0.9023668639053254,
#   0.908284023668639,
#   0.915680473372781,
#   0.9112426035502958,
#   0.915680473372781,
#   0.9452662721893491],
#  '6T_Acc': [0.9263456090651558,
#   0.9348441926345609,
#   0.9447592067988668,
#   0.943342776203966,
#   0.953257790368272,
#   0.9419263456090652,
#   0.943342776203966,
#   0.9475920679886686,
#   0.9575070821529745,
#   0.9518413597733711],
#  '7T_Acc': [0.8569553805774278,
#   0.8976377952755905,
#   0.9028871391076115,
#   0.916010498687664,
#   0.89501312335958,
#   0.9212598425196851,
#   0.9094488188976378,
#   0.937007874015748,
#   0.9304461942257218,
#   0.9304461942257218],
#  '8T_Acc': [0.8590971272229823,
#   0.8549931600547196,
#   0.8686730506155951,
#   0.8974008207934336,
#   0.9124487004103967,
#   0.9247606019151847,
#   0.9261285909712722,
#   0.9274965800273598,
#   0.9439124487004104,
#   0.9411764705882353],
#  '9T_Acc': [0.8608582574772432,
#   0.8842652795838751,
#   0.8803641092327699,
#   0.893368010403121,
#   0.8881664499349805,
#   0.9219765929778934,
#   0.9375812743823146,
#   0.9141742522756827,
#   0.9219765929778934,
#   0.9310793237971391],
#  'cm_per_epoch': [array([[692,   0,   2,   0,   0,   8,  12,   1,   4,   0,   0, 821,   2,
#             5,   1,   0,   4,   1,  15,   0,   5,  10, 670,  14,  12,   1,
#            17,  14,  38,   3,   3,   2,  17, 649,   2,  38,   3,  11,  25,
#             5,   1,   3,   3,   2, 681,   0,  10,   1,   5,  43,  12,   4,
#             2,  30,   9, 560,  13,   4,  33,   9,  15,   3,   4,   0,  10,
#            15, 654,   0,   5,   0,   2,  29,  14,   4,  13,   0,   0, 653,
#             5,  42,   7,   8,  11,  13,  12,  20,   8,  12, 628,  12,  11,
#             5,   1,  10,  40,  11,   2,  13,  14, 662]]),
#   array([[701,   0,   1,   0,   0,   4,   9,   1,   3,   0,   0, 830,   3,
#             3,   1,   0,   3,   1,   8,   0,   7,  12, 694,   6,  11,   1,
#            14,  15,  24,   0,   3,   3,  20, 661,   1,  29,   1,  16,  12,
#             9,   1,   4,   3,   0, 689,   0,  12,   3,   2,  35,  16,   1,
#             2,  22,   7, 588,   8,   7,  18,   7,  15,   3,   2,   0,  13,
#            10, 660,   0,   3,   0,   2,  18,  17,   2,  10,   0,   0, 684,
#             0,  29,  10,   8,  11,  10,  11,  22,   8,  15, 625,  11,  11,
#             6,   1,   7,  32,   8,   1,  18,   5, 680]]),
#   array([[701,   0,   1,   0,   0,   4,   9,   1,   3,   0,   0, 828,   3,
#             5,   1,   0,   3,   1,   8,   0,   6,   3, 714,   7,  10,   1,
#            15,  11,  17,   0,   3,   2,  15, 691,   2,  20,   1,  12,   6,
#             3,   1,   3,   2,   1, 704,   1,  12,   2,   3,  20,   8,   1,
#             2,  29,   2, 600,   9,   5,  15,   5,  11,   3,   3,   0,   9,
#            10, 667,   0,   3,   0,   3,  12,  20,   3,  11,   0,   1, 688,
#             2,  22,   7,   6,  10,  18,  11,  21,   8,  11, 635,   4,  11,
#             5,   0,  14,  34,   7,   1,  12,   8, 677]]),
#   array([[702,   0,   1,   0,   0,   3,  10,   1,   2,   0,   0, 832,   3,
#             3,   0,   0,   3,   1,   7,   0,   6,   5, 715,   8,   9,   1,
#            12,  10,  18,   0,   3,   1,  16, 688,   1,  19,   2,  14,   9,
#             2,   1,   2,   2,   0, 698,   0,  14,   2,   3,  27,   7,   1,
#             2,  13,   2, 612,   7,   5,  21,   6,  11,   3,   3,   0,  10,
#            10, 666,   0,   3,   0,   3,  15,  16,   3,   9,   0,   1, 698,
#             2,  15,   5,   6,   6,  12,  10,  18,   7,   9, 656,   2,   8,
#             6,   0,  11,  27,   6,   1,  14,   9, 687]]),
#   array([[704,   0,   1,   0,   0,   2,   9,   1,   2,   0,   0, 832,   3,
#             3,   0,   0,   3,   1,   7,   0,   6,   4, 733,   7,   5,   0,
#            11,   9,   9,   0,   2,   1,  18, 703,   1,  13,   1,   7,   6,
#             3,   1,   2,   3,   0, 707,   0,  14,   2,   4,  16,   7,   1,
#             2,  20,   2, 610,   8,   3,  17,   6,  10,   3,   4,   0,   8,
#             6, 673,   0,   2,   0,   3,  14,  26,   5,  10,   0,   1, 682,
#             1,  20,   5,   3,  10,  14,   9,   7,   6,   7, 667,   3,   8,
#             6,   0,  11,  34,   7,   2,   9,   9, 683]]),
#   array([[706,   0,   1,   0,   0,   2,   7,   1,   2,   0,   0, 833,   3,
#             3,   0,   0,   3,   1,   6,   0,   3,   4, 737,   8,   6,   0,
#             6,  10,  10,   0,   1,   1,  13, 706,   1,  11,   1,  11,   7,
#             3,   1,   2,   3,   0, 694,   0,  10,   2,   4,  33,   7,   1,
#             2,  17,   3, 614,   6,   4,  14,   8,   9,   3,   4,   0,  11,
#            10, 665,   0,   4,   0,   3,  11,  14,   3,   6,   0,   0, 702,
#             1,  22,   4,   3,   8,  11,   8,   7,   3,   9, 676,   2,   6,
#             6,   1,  11,  14,   5,   1,   9,   7, 709]]),
#   array([[708,   0,   0,   0,   0,   2,   6,   1,   2,   0,   0, 834,   2,
#             3,   0,   0,   3,   1,   6,   0,   6,   5, 725,   9,   9,   0,
#             7,  11,  11,   1,   1,   1,  12, 709,   1,  11,   1,   8,   6,
#             5,   1,   1,   2,   0, 705,   0,   9,   2,   2,  27,   7,   1,
#             0,  12,   6, 619,   7,   2,  13,   9,  11,   3,   2,   0,  15,
#             5, 666,   0,   4,   0,   2,  10,  11,   5,   7,   0,   0, 693,
#             1,  33,   5,   3,   2,  11,  10,   9,   3,   6, 677,   5,   8,
#             5,   0,   9,  10,   3,   0,   5,   8, 721]]),
#   array([[707,   0,   0,   0,   0,   2,   7,   1,   2,   0,   0, 833,   3,
#             3,   0,   1,   3,   1,   5,   0,   4,   2, 740,   6,   7,   0,
#             6,  10,   9,   0,   1,   1,  14, 710,   1,   9,   0,  11,   5,
#             3,   1,   1,   3,   0, 711,   0,  10,   2,   2,  19,   8,   1,
#             1,  16,   5, 616,   5,   4,  12,   8,  10,   3,   4,   0,   9,
#             5, 669,   1,   5,   0,   2,  11,  12,   2,   4,   0,   0, 714,
#             1,  16,   5,   4,   3,   9,   9,   9,   3,   8, 678,   3,  11,
#             5,   1,   8,  19,   3,   0,  11,   8, 703]]),
#   array([[707,   0,   0,   0,   0,   2,   7,   1,   2,   0,   0, 833,   3,
#             3,   0,   1,   3,   1,   5,   0,   8,   4, 737,   4,   5,   0,
#             7,   9,  10,   0,   3,   1,  12, 707,   0,  11,   0,   9,   8,
#             4,   1,   1,   3,   0, 711,   0,  10,   2,   2,  19,   8,   1,
#             0,  12,   4, 619,   7,   3,  16,   6,  10,   3,   1,   0,   9,
#             3, 676,   0,   4,   0,   3,  13,   9,   2,   4,   0,   0, 709,
#             1,  21,   6,   2,   3,   6,   7,   4,   3,   6, 690,   4,   9,
#             5,   1,   7,  17,   2,   1,   8,  10, 709]]),
#   array([[708,   0,   0,   0,   0,   2,   6,   1,   2,   0,   0, 833,   3,
#             3,   0,   1,   3,   1,   5,   0,   9,   2, 741,   4,   6,   0,
#             6,   7,   9,   0,   2,   1,  13, 710,   0,  11,   0,   9,   6,
#             3,   1,   1,   3,   0, 708,   0,  10,   2,   2,  22,   6,   1,
#             1,  10,   3, 639,   5,   1,   6,   4,  11,   3,   2,   0,   7,
#             6, 672,   1,   4,   0,   3,  12,  10,   4,   3,   0,   0, 709,
#             2,  19,   5,   2,   3,   9,   6,   8,   4,   3, 688,   3,   9,
#             4,   0,   6,  13,   4,   0,   7,  10, 716]])],
#  'f1_micro': [0.8893333333333333,
#   0.9082666666666667,
#   0.9206666666666665,
#   0.9271999999999999,
#   0.9325333333333332,
#   0.9389333333333333,
#   0.9409333333333333,
#   0.9441333333333334,
#   0.9464,
#   0.9498666666666666],
#  'f1_macro': [0.8882316895423983,
#   0.9072518662116483,
#   0.9197360516359291,
#   0.9264820191134351,
#   0.931972978287852,
#   0.9384673106675727,
#   0.9405359329313174,
#   0.9436488419240806,
#   0.9460104110230461,
#   0.949551013436824],
#  'f1_weighted': [0.8891085314112255,
#   0.9079025892372772,
#   0.9204106988444479,
#   0.9270294840723878,
#   0.932334440820145,
#   0.9388403449359909,
#   0.9408761285614053,
#   0.9440280897727742,
#   0.9463276804030822,
#   0.9498106108156728],
#  'f1_notweighted': [array([0.94342195, 0.94694348, 0.88741722, 0.87584345, 0.89077829,
#          0.8427389 , 0.9153254 , 0.88722826, 0.83566201, 0.85695793]),
#   array([0.94410774, 0.95732411, 0.90247074, 0.90177353, 0.90419948,
#          0.87892377, 0.92827004, 0.89881735, 0.87351502, 0.88311688]),
#   array([0.9537415 , 0.96728972, 0.91891892, 0.90741957, 0.91846053,
#          0.89552239, 0.93156425, 0.91428571, 0.88749126, 0.90266667]),
#   array([0.95836177, 0.96744186, 0.92377261, 0.92163429, 0.92145215,
#          0.91003717, 0.93212036, 0.92084433, 0.89801506, 0.91114058]),
#   array([0.96109215, 0.97026239, 0.92550505, 0.92621871, 0.92721311,
#          0.92354277, 0.93863319, 0.91975725, 0.91683849, 0.91066667]),
#   array([0.96778615, 0.97256276, 0.9388535 , 0.9326288 , 0.93029491,
#          0.92679245, 0.94460227, 0.92918597, 0.9247606 , 0.91720569]),
#   array([0.96457766, 0.97429907, 0.94155844, 0.93721084, 0.93253968,
#          0.93433962, 0.94602273, 0.92957746, 0.92676249, 0.91847134]),
#   array([0.96321526, 0.97426901, 0.9456869 , 0.94102054, 0.93923382,
#          0.9326268 , 0.94960965, 0.93639344, 0.93004115, 0.92439185]),
#   array([0.95929444, 0.97313084, 0.94913071, 0.94518717, 0.94422311,
#          0.93930197, 0.95211268, 0.93907285, 0.93306288, 0.92558747]),
#   array([0.96130346, 0.97540984, 0.95      , 0.94603598, 0.94715719,
#          0.94877506, 0.95184136, 0.94344644, 0.93924915, 0.93229167])]}

# %% [markdown]
# ##### Function plot_model_history_all to model Train and Val Acc, Loss curves

# %%
#@title: plot_model_history_all
def plot_model_history_all(model_history, nb_epoch=None, cm3=None): 
  # Parameters
  # ----------
  # tot_epochs : int
  #     Total number of epochs for which the model was trained.
  # model_history : keras.callbacks.History
  #     The history object returned by the fit() method of the model.
  # cm3 : 10x10 dataframe 
  #      10x10 dataframe of confusion matrix from predicted X_val categories
  # restored_weights : int
  #     The epoch at which the weights were restored.

  

  tot_epochs = max(model_history.epoch)+1  #if the total epochs ran is 28, it'll show up as 27 in the epoch object so we must add 1
  # print("Total Epochs: ", tot_epochs)

  #if tot_epochs is the total number of epochs ran then early stop did not happen, and we need not minus patience
  if tot_epochs == nb_epoch:
    restored_weights = tot_epochs
  else:
    restored_weights  = tot_epochs-patience   #when using restore-best-weights and patience, it'll restore the best weights back
  # print("Restored weights at ", restored_weights, "Patience used: ", patience)

  ax[0].plot(range(1,tot_epochs+1), model_history.history['categorical_accuracy'], color='blue',           )
  ax[0].plot(range(1,tot_epochs+1), model_history.history['val_categorical_accuracy'] , color='orange',    )
  ax[0].scatter((restored_weights), model_history.history['val_categorical_accuracy'][restored_weights-1] , color='orange')
  ax[0].scatter(restored_weights, model_history.history['categorical_accuracy'][restored_weights-1], color='blue')
  ax[0].annotate(text=str(restored_weights),  xy=(restored_weights, model_history.history['val_categorical_accuracy'][restored_weights-1]),
                  textcoords="offset points", xytext=(0,10), ha='center', color='black')
  # ax[0].legend()
  ax[0].set_title('Training (Blue) and Validation (Orange) Accuracy', fontsize='8')

  ax[1].plot(range(1,tot_epochs+1), model_history.history['loss'], color= 'blue',  )
  ax[1].plot(range(1,tot_epochs+1), model_history.history['val_loss'], color='orange',  )
  ax[1].scatter(restored_weights, model_history.history['loss'][restored_weights-1], color='blue')
  ax[1].scatter((restored_weights), model_history.history['val_loss'][restored_weights-1] , color='orange')
  ax[1].annotate(text=str(restored_weights),  xy=(restored_weights, model_history.history['val_loss'][restored_weights-1]),
                  textcoords="offset points", xytext=(0,10), ha='center')
  # ax[1].legend()
  ax[1].set_title('Training (Blue) and Validation (Orange) Loss' , fontsize='8')


  plt.gcf().set_size_inches(10, 5)  # this works 
  # plt.gcf().suptitle(f"Lambda Value {lambda_val} for {nb_epoch} Epochs and Patience {patience} " )

# %% [markdown]
# ##### Plot the first five epochs of training

# %%
#Learning Rate 0.1
fig = plt.figure(figsize=(20, 10)) 
fig, ax = plt.subplots(1,2)
plot_model_history_all(model_history, 5)
plt.show()

# %%
#Learning Rate 0.001
# fig = plt.figure(figsize=(20, 10)) 
# fig, ax = plt.subplots(1,2)
# plot_model_history_all(model_history, 5)
# plt.show()

# %%
# #Learning Rate 0.01
# fig = plt.figure(figsize=(20, 10)) 
# fig, ax = plt.subplots(1,2)
# plot_model_history_all(model_history, 5)
# plt.show()

# %% [markdown]
# The code below to generate variations of the model training / validation results after training with a cost matrix 30 times did not produce any variability.   Therefore I want to shuffle the training/validation deck randomly between training sessions to see if that helps introduce some randomness.

# %% [markdown]
# #### The Training Runs - Commented out to ensure not run again when the notebook is saved with output

# %% [markdown]
# This takes hours to run for about 40 replications so usually after running, I save the out put to GitHub for easy lookup later

# %%
#@title

## -----------------------------------------------------------------------------------------------------
## Now we need to load the weights of the model, and continue training with a different cost matrix
## ------------------------------------------------------------------------------------------------------
# load the model weights
# model.load_weights('initial_5epochs.h5') 

cost_matrix = np.ones((10,10))

model_history_all = []
cm_all            = []

cost_list = [10, 100, 1000, 1] # Each one takes about 2 minutes 5*4*2=40 minutes for 5 costs/4 reps -- actually all took 40 reps took almost  1.5 hours

for k in cost_list:
  for i in range(1):


    cost_matrix[9,4] = k
    model = create_model()

    model.load_weights('initial_10epochs.h5')

    #I may need to re-initiate the optimizer to have a smaller learning rate
    model.compile(loss=WeightedCategoricalCrossentropy(cost_matrix), optimizer=sgd,  metrics='categorical_accuracy',)
    
    nb_epoch = 140
    # patience = 20

    # es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, verbose=1, restore_best_weights = True)

    X_train_shuffled = shuffle(X_train, random_state=42+i)
    Y_train_shuffled = shuffle(Y_train, random_state=42+i)
 

    history = model.fit(X_train_shuffled, Y_train_shuffled,          batch_size=batch_size, epochs=nb_epoch, verbose=1,
            validation_data=(X_val, Y_val), shuffle=True, use_multiprocessing=True, callbacks = [ cm_callback, f1_callback])

    cm3 = return_cm(model)

    del(history.model)

    model_history_all.append(history)
    
    cm_all.append(cm3)



    from google.colab import files
    import pickle
    # save the variable to a pickle file
    with open('initial_10_secondphase_lambda_history.pkl', 'wb') as f:
          pickle.dump(model_history_all, f)
    files.download('initial_10_secondphase_lambda_history.pkl')
    with open('initial_10_secondphase_lambda_cm.pkl', 'wb') as f:
        pickle.dump(cm_all, f)
    files.download('initial_10_secondphase_lambda_cm.pkl')

    ## Now I need to plot all of the "model_history_all"
  
  # # print(model_history_all)
  # fig = plt.figure(figsize=(20, 10)) 
  # fig, ax = plt.subplots(1,3)
  # for item in (model_history_all):
  #     # print(item)
  #   plot_model_history_all(item)



  # print(model_history_all) #18 items into _ is taking 1 hours and 3 minutes!  perhaps im not usng the right settings - i have no-accelerator on google colab
# Out:
# Streaming output truncated to the last 5000 lines.
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1678 - categorical_accuracy: 0.9509 - val_loss: 0.2701 - val_categorical_accuracy: 0.9571 - 9T_4P: 4.0000 - 4T_9P: 61.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9847 - 2T_Acc: 0.9719 - 3T_Acc: 0.9576 - 4T_Acc: 0.8985 - 5T_Acc: 0.9571 - 6T_Acc: 0.9717 - 7T_Acc: 0.9462 - 8T_Acc: 0.9425 - 9T_Acc: 0.9519 - cm_per_epoch: 75.0000 - f1_micro: 0.9571 - f1_macro: 0.9569 - f1_weighted: 0.9570 - f1_notweighted: 0.9569
# Epoch 93/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1630 - categorical_accuracy: 0.9502 - val_loss: 0.2832 - val_categorical_accuracy: 0.9596 - 9T_4P: 5.0000 - 4T_9P: 56.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9847 - 2T_Acc: 0.9681 - 3T_Acc: 0.9563 - 4T_Acc: 0.9065 - 5T_Acc: 0.9556 - 6T_Acc: 0.9759 - 7T_Acc: 0.9554 - 8T_Acc: 0.9521 - 9T_Acc: 0.9519 - cm_per_epoch: 75.0000 - f1_micro: 0.9596 - f1_macro: 0.9595 - f1_weighted: 0.9596 - f1_notweighted: 0.9595
# Epoch 94/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1641 - categorical_accuracy: 0.9522 - val_loss: 0.3673 - val_categorical_accuracy: 0.9620 - 9T_4P: 4.0000 - 4T_9P: 34.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9859 - 2T_Acc: 0.9719 - 3T_Acc: 0.9589 - 4T_Acc: 0.9386 - 5T_Acc: 0.9512 - 6T_Acc: 0.9703 - 7T_Acc: 0.9528 - 8T_Acc: 0.9508 - 9T_Acc: 0.9506 - cm_per_epoch: 75.0000 - f1_micro: 0.9620 - f1_macro: 0.9618 - f1_weighted: 0.9620 - f1_notweighted: 0.9618
# Epoch 95/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1986 - categorical_accuracy: 0.9452 - val_loss: 0.3892 - val_categorical_accuracy: 0.9560 - 9T_4P: 7.0000 - 4T_9P: 48.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9800 - 2T_Acc: 0.9732 - 3T_Acc: 0.9351 - 4T_Acc: 0.9146 - 5T_Acc: 0.9556 - 6T_Acc: 0.9703 - 7T_Acc: 0.9541 - 8T_Acc: 0.9439 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9560 - f1_macro: 0.9558 - f1_weighted: 0.9559 - f1_notweighted: 0.9558
# Epoch 96/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1814 - categorical_accuracy: 0.9449 - val_loss: 0.2584 - val_categorical_accuracy: 0.9597 - 9T_4P: 4.0000 - 4T_9P: 41.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9835 - 2T_Acc: 0.9694 - 3T_Acc: 0.9536 - 4T_Acc: 0.9212 - 5T_Acc: 0.9541 - 6T_Acc: 0.9731 - 7T_Acc: 0.9633 - 8T_Acc: 0.9466 - 9T_Acc: 0.9467 - cm_per_epoch: 75.0000 - f1_micro: 0.9597 - f1_macro: 0.9595 - f1_weighted: 0.9597 - f1_notweighted: 0.9595
# Epoch 97/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1668 - categorical_accuracy: 0.9494 - val_loss: 0.3131 - val_categorical_accuracy: 0.9597 - 9T_4P: 6.0000 - 4T_9P: 51.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9812 - 2T_Acc: 0.9668 - 3T_Acc: 0.9563 - 4T_Acc: 0.9119 - 5T_Acc: 0.9556 - 6T_Acc: 0.9745 - 7T_Acc: 0.9606 - 8T_Acc: 0.9466 - 9T_Acc: 0.9558 - cm_per_epoch: 75.0000 - f1_micro: 0.9597 - f1_macro: 0.9596 - f1_weighted: 0.9597 - f1_notweighted: 0.9596
# Epoch 98/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1733 - categorical_accuracy: 0.9477 - val_loss: 0.3273 - val_categorical_accuracy: 0.9567 - 9T_4P: 4.0000 - 4T_9P: 65.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9800 - 2T_Acc: 0.9694 - 3T_Acc: 0.9483 - 4T_Acc: 0.8932 - 5T_Acc: 0.9601 - 6T_Acc: 0.9731 - 7T_Acc: 0.9567 - 8T_Acc: 0.9521 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9567 - f1_macro: 0.9565 - f1_weighted: 0.9566 - f1_notweighted: 0.9565
# Epoch 99/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1579 - categorical_accuracy: 0.9523 - val_loss: 0.3507 - val_categorical_accuracy: 0.9609 - 9T_4P: 6.0000 - 4T_9P: 35.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9835 - 2T_Acc: 0.9643 - 3T_Acc: 0.9536 - 4T_Acc: 0.9346 - 5T_Acc: 0.9601 - 6T_Acc: 0.9745 - 7T_Acc: 0.9580 - 8T_Acc: 0.9466 - 9T_Acc: 0.9493 - cm_per_epoch: 75.0000 - f1_micro: 0.9609 - f1_macro: 0.9608 - f1_weighted: 0.9609 - f1_notweighted: 0.9608
# Epoch 100/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1598 - categorical_accuracy: 0.9530 - val_loss: 0.3035 - val_categorical_accuracy: 0.9585 - 9T_4P: 6.0000 - 4T_9P: 57.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9823 - 2T_Acc: 0.9783 - 3T_Acc: 0.9563 - 4T_Acc: 0.9012 - 5T_Acc: 0.9512 - 6T_Acc: 0.9745 - 7T_Acc: 0.9488 - 8T_Acc: 0.9549 - 9T_Acc: 0.9493 - cm_per_epoch: 75.0000 - f1_micro: 0.9585 - f1_macro: 0.9584 - f1_weighted: 0.9585 - f1_notweighted: 0.9584
# Epoch 101/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1780 - categorical_accuracy: 0.9484 - val_loss: 0.2588 - val_categorical_accuracy: 0.9593 - 9T_4P: 5.0000 - 4T_9P: 45.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9812 - 2T_Acc: 0.9617 - 3T_Acc: 0.9576 - 4T_Acc: 0.9199 - 5T_Acc: 0.9512 - 6T_Acc: 0.9745 - 7T_Acc: 0.9659 - 8T_Acc: 0.9412 - 9T_Acc: 0.9519 - cm_per_epoch: 75.0000 - f1_micro: 0.9593 - f1_macro: 0.9591 - f1_weighted: 0.9593 - f1_notweighted: 0.9591
# Epoch 102/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1759 - categorical_accuracy: 0.9472 - val_loss: 0.2323 - val_categorical_accuracy: 0.9577 - 9T_4P: 3.0000 - 4T_9P: 52.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9835 - 2T_Acc: 0.9694 - 3T_Acc: 0.9457 - 4T_Acc: 0.9105 - 5T_Acc: 0.9630 - 6T_Acc: 0.9759 - 7T_Acc: 0.9541 - 8T_Acc: 0.9371 - 9T_Acc: 0.9506 - cm_per_epoch: 75.0000 - f1_micro: 0.9577 - f1_macro: 0.9575 - f1_weighted: 0.9577 - f1_notweighted: 0.9575
# Epoch 103/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1691 - categorical_accuracy: 0.9492 - val_loss: 0.2393 - val_categorical_accuracy: 0.9581 - 9T_4P: 3.0000 - 4T_9P: 58.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9847 - 2T_Acc: 0.9694 - 3T_Acc: 0.9536 - 4T_Acc: 0.9025 - 5T_Acc: 0.9497 - 6T_Acc: 0.9745 - 7T_Acc: 0.9659 - 8T_Acc: 0.9412 - 9T_Acc: 0.9519 - cm_per_epoch: 75.0000 - f1_micro: 0.9581 - f1_macro: 0.9579 - f1_weighted: 0.9581 - f1_notweighted: 0.9579
# Epoch 104/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1681 - categorical_accuracy: 0.9503 - val_loss: 0.2443 - val_categorical_accuracy: 0.9537 - 9T_4P: 3.0000 - 4T_9P: 103.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9870 - 2T_Acc: 0.9694 - 3T_Acc: 0.9576 - 4T_Acc: 0.8438 - 5T_Acc: 0.9660 - 6T_Acc: 0.9745 - 7T_Acc: 0.9606 - 8T_Acc: 0.9412 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9537 - f1_macro: 0.9536 - f1_weighted: 0.9536 - f1_notweighted: 0.9536
# Epoch 105/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1610 - categorical_accuracy: 0.9506 - val_loss: 0.3898 - val_categorical_accuracy: 0.9609 - 9T_4P: 6.0000 - 4T_9P: 38.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9847 - 2T_Acc: 0.9694 - 3T_Acc: 0.9616 - 4T_Acc: 0.9319 - 5T_Acc: 0.9601 - 6T_Acc: 0.9717 - 7T_Acc: 0.9593 - 8T_Acc: 0.9398 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9609 - f1_macro: 0.9607 - f1_weighted: 0.9609 - f1_notweighted: 0.9607
# Epoch 106/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1888 - categorical_accuracy: 0.9459 - val_loss: 0.2142 - val_categorical_accuracy: 0.9572 - 9T_4P: 4.0000 - 4T_9P: 63.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9847 - 2T_Acc: 0.9656 - 3T_Acc: 0.9629 - 4T_Acc: 0.8945 - 5T_Acc: 0.9527 - 6T_Acc: 0.9674 - 7T_Acc: 0.9554 - 8T_Acc: 0.9384 - 9T_Acc: 0.9597 - cm_per_epoch: 75.0000 - f1_micro: 0.9572 - f1_macro: 0.9570 - f1_weighted: 0.9572 - f1_notweighted: 0.9570
# Epoch 107/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1847 - categorical_accuracy: 0.9450 - val_loss: 0.3732 - val_categorical_accuracy: 0.9572 - 9T_4P: 7.0000 - 4T_9P: 43.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9800 - 2T_Acc: 0.9668 - 3T_Acc: 0.9536 - 4T_Acc: 0.9252 - 5T_Acc: 0.9467 - 6T_Acc: 0.9660 - 7T_Acc: 0.9567 - 8T_Acc: 0.9384 - 9T_Acc: 0.9493 - cm_per_epoch: 75.0000 - f1_micro: 0.9572 - f1_macro: 0.9571 - f1_weighted: 0.9572 - f1_notweighted: 0.9571
# Epoch 108/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1760 - categorical_accuracy: 0.9460 - val_loss: 0.3384 - val_categorical_accuracy: 0.9579 - 9T_4P: 6.0000 - 4T_9P: 56.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9823 - 2T_Acc: 0.9707 - 3T_Acc: 0.9589 - 4T_Acc: 0.9079 - 5T_Acc: 0.9541 - 6T_Acc: 0.9717 - 7T_Acc: 0.9554 - 8T_Acc: 0.9466 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9579 - f1_macro: 0.9577 - f1_weighted: 0.9578 - f1_notweighted: 0.9577
# Epoch 109/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1567 - categorical_accuracy: 0.9531 - val_loss: 0.2067 - val_categorical_accuracy: 0.9559 - 9T_4P: 2.0000 - 4T_9P: 74.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9859 - 2T_Acc: 0.9694 - 3T_Acc: 0.9616 - 4T_Acc: 0.8838 - 5T_Acc: 0.9675 - 6T_Acc: 0.9632 - 7T_Acc: 0.9409 - 8T_Acc: 0.9398 - 9T_Acc: 0.9571 - cm_per_epoch: 75.0000 - f1_micro: 0.9559 - f1_macro: 0.9559 - f1_weighted: 0.9559 - f1_notweighted: 0.9559
# Epoch 110/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1615 - categorical_accuracy: 0.9517 - val_loss: 0.3811 - val_categorical_accuracy: 0.9639 - 9T_4P: 7.0000 - 4T_9P: 28.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9847 - 2T_Acc: 0.9758 - 3T_Acc: 0.9669 - 4T_Acc: 0.9426 - 5T_Acc: 0.9527 - 6T_Acc: 0.9731 - 7T_Acc: 0.9554 - 8T_Acc: 0.9508 - 9T_Acc: 0.9467 - cm_per_epoch: 75.0000 - f1_micro: 0.9639 - f1_macro: 0.9637 - f1_weighted: 0.9638 - f1_notweighted: 0.9637
# Epoch 111/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1577 - categorical_accuracy: 0.9537 - val_loss: 0.3819 - val_categorical_accuracy: 0.9617 - 9T_4P: 5.0000 - 4T_9P: 37.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9835 - 2T_Acc: 0.9732 - 3T_Acc: 0.9563 - 4T_Acc: 0.9306 - 5T_Acc: 0.9527 - 6T_Acc: 0.9731 - 7T_Acc: 0.9619 - 8T_Acc: 0.9453 - 9T_Acc: 0.9532 - cm_per_epoch: 75.0000 - f1_micro: 0.9617 - f1_macro: 0.9614 - f1_weighted: 0.9617 - f1_notweighted: 0.9614
# Epoch 112/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1537 - categorical_accuracy: 0.9551 - val_loss: 0.3126 - val_categorical_accuracy: 0.9607 - 9T_4P: 6.0000 - 4T_9P: 52.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9859 - 2T_Acc: 0.9707 - 3T_Acc: 0.9603 - 4T_Acc: 0.9092 - 5T_Acc: 0.9630 - 6T_Acc: 0.9731 - 7T_Acc: 0.9606 - 8T_Acc: 0.9521 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9607 - f1_macro: 0.9605 - f1_weighted: 0.9606 - f1_notweighted: 0.9605
# Epoch 113/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1658 - categorical_accuracy: 0.9509 - val_loss: 0.2966 - val_categorical_accuracy: 0.9580 - 9T_4P: 3.0000 - 4T_9P: 69.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9835 - 2T_Acc: 0.9770 - 3T_Acc: 0.9589 - 4T_Acc: 0.8865 - 5T_Acc: 0.9571 - 6T_Acc: 0.9745 - 7T_Acc: 0.9514 - 8T_Acc: 0.9466 - 9T_Acc: 0.9558 - cm_per_epoch: 75.0000 - f1_micro: 0.9580 - f1_macro: 0.9578 - f1_weighted: 0.9580 - f1_notweighted: 0.9578
# Epoch 114/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1722 - categorical_accuracy: 0.9492 - val_loss: 0.3201 - val_categorical_accuracy: 0.9597 - 9T_4P: 3.0000 - 4T_9P: 46.0000 - 0T_Acc: 0.9819 - 1T_Acc: 0.9847 - 2T_Acc: 0.9732 - 3T_Acc: 0.9536 - 4T_Acc: 0.9186 - 5T_Acc: 0.9689 - 6T_Acc: 0.9759 - 7T_Acc: 0.9488 - 8T_Acc: 0.9425 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9597 - f1_macro: 0.9596 - f1_weighted: 0.9597 - f1_notweighted: 0.9596
# Epoch 115/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1577 - categorical_accuracy: 0.9518 - val_loss: 0.2655 - val_categorical_accuracy: 0.9583 - 9T_4P: 3.0000 - 4T_9P: 70.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9847 - 2T_Acc: 0.9732 - 3T_Acc: 0.9536 - 4T_Acc: 0.8865 - 5T_Acc: 0.9630 - 6T_Acc: 0.9745 - 7T_Acc: 0.9541 - 8T_Acc: 0.9508 - 9T_Acc: 0.9571 - cm_per_epoch: 75.0000 - f1_micro: 0.9583 - f1_macro: 0.9581 - f1_weighted: 0.9582 - f1_notweighted: 0.9581
# Epoch 116/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1776 - categorical_accuracy: 0.9472 - val_loss: 0.3506 - val_categorical_accuracy: 0.9569 - 9T_4P: 5.0000 - 4T_9P: 50.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9812 - 2T_Acc: 0.9643 - 3T_Acc: 0.9523 - 4T_Acc: 0.9159 - 5T_Acc: 0.9512 - 6T_Acc: 0.9731 - 7T_Acc: 0.9554 - 8T_Acc: 0.9371 - 9T_Acc: 0.9532 - cm_per_epoch: 75.0000 - f1_micro: 0.9569 - f1_macro: 0.9567 - f1_weighted: 0.9569 - f1_notweighted: 0.9567
# Epoch 117/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1703 - categorical_accuracy: 0.9507 - val_loss: 0.2583 - val_categorical_accuracy: 0.9577 - 9T_4P: 3.0000 - 4T_9P: 77.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9835 - 2T_Acc: 0.9745 - 3T_Acc: 0.9589 - 4T_Acc: 0.8785 - 5T_Acc: 0.9675 - 6T_Acc: 0.9745 - 7T_Acc: 0.9462 - 8T_Acc: 0.9494 - 9T_Acc: 0.9545 - cm_per_epoch: 75.0000 - f1_micro: 0.9577 - f1_macro: 0.9577 - f1_weighted: 0.9577 - f1_notweighted: 0.9577
# Epoch 118/140
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1519 - categorical_accuracy: 0.9535 - val_loss: 0.3249 - val_categorical_accuracy: 0.9597 - 9T_4P: 4.0000 - 4T_9P: 46.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9847 - 2T_Acc: 0.9745 - 3T_Acc: 0.9457 - 4T_Acc: 0.9186 - 5T_Acc: 0.9601 - 6T_Acc: 0.9745 - 7T_Acc: 0.9488 - 8T_Acc: 0.9453 - 9T_Acc: 0.9571 - cm_per_epoch: 75.0000 - f1_micro: 0.9597 - f1_macro: 0.9595 - f1_weighted: 0.9597 - f1_notweighted: 0.9595
# Epoch 119/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1560 - categorical_accuracy: 0.9535 - val_loss: 0.3464 - val_categorical_accuracy: 0.9601 - 9T_4P: 5.0000 - 4T_9P: 46.0000 - 0T_Acc: 0.9819 - 1T_Acc: 0.9812 - 2T_Acc: 0.9758 - 3T_Acc: 0.9523 - 4T_Acc: 0.9172 - 5T_Acc: 0.9645 - 6T_Acc: 0.9745 - 7T_Acc: 0.9501 - 8T_Acc: 0.9494 - 9T_Acc: 0.9532 - cm_per_epoch: 75.0000 - f1_micro: 0.9601 - f1_macro: 0.9600 - f1_weighted: 0.9601 - f1_notweighted: 0.9600
# Epoch 120/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1486 - categorical_accuracy: 0.9560 - val_loss: 0.5609 - val_categorical_accuracy: 0.9595 - 9T_4P: 5.0000 - 4T_9P: 39.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9835 - 2T_Acc: 0.9732 - 3T_Acc: 0.9563 - 4T_Acc: 0.9332 - 5T_Acc: 0.9645 - 6T_Acc: 0.9632 - 7T_Acc: 0.9501 - 8T_Acc: 0.9330 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9595 - f1_macro: 0.9593 - f1_weighted: 0.9594 - f1_notweighted: 0.9593
# Epoch 121/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1728 - categorical_accuracy: 0.9483 - val_loss: 0.3519 - val_categorical_accuracy: 0.9609 - 9T_4P: 4.0000 - 4T_9P: 43.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9823 - 2T_Acc: 0.9770 - 3T_Acc: 0.9576 - 4T_Acc: 0.9266 - 5T_Acc: 0.9601 - 6T_Acc: 0.9717 - 7T_Acc: 0.9462 - 8T_Acc: 0.9453 - 9T_Acc: 0.9532 - cm_per_epoch: 75.0000 - f1_micro: 0.9609 - f1_macro: 0.9608 - f1_weighted: 0.9609 - f1_notweighted: 0.9608
# Epoch 122/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1526 - categorical_accuracy: 0.9535 - val_loss: 0.3303 - val_categorical_accuracy: 0.9589 - 9T_4P: 3.0000 - 4T_9P: 70.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9847 - 2T_Acc: 0.9707 - 3T_Acc: 0.9589 - 4T_Acc: 0.8892 - 5T_Acc: 0.9675 - 6T_Acc: 0.9759 - 7T_Acc: 0.9593 - 8T_Acc: 0.9412 - 9T_Acc: 0.9571 - cm_per_epoch: 75.0000 - f1_micro: 0.9589 - f1_macro: 0.9588 - f1_weighted: 0.9589 - f1_notweighted: 0.9588
# Epoch 123/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1488 - categorical_accuracy: 0.9554 - val_loss: 0.4657 - val_categorical_accuracy: 0.9600 - 9T_4P: 6.0000 - 4T_9P: 41.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9847 - 2T_Acc: 0.9719 - 3T_Acc: 0.9576 - 4T_Acc: 0.9252 - 5T_Acc: 0.9675 - 6T_Acc: 0.9731 - 7T_Acc: 0.9475 - 8T_Acc: 0.9384 - 9T_Acc: 0.9467 - cm_per_epoch: 75.0000 - f1_micro: 0.9600 - f1_macro: 0.9598 - f1_weighted: 0.9600 - f1_notweighted: 0.9598
# Epoch 124/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1771 - categorical_accuracy: 0.9480 - val_loss: 0.2713 - val_categorical_accuracy: 0.9563 - 9T_4P: 3.0000 - 4T_9P: 72.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9847 - 2T_Acc: 0.9707 - 3T_Acc: 0.9576 - 4T_Acc: 0.8812 - 5T_Acc: 0.9645 - 6T_Acc: 0.9717 - 7T_Acc: 0.9501 - 8T_Acc: 0.9494 - 9T_Acc: 0.9454 - cm_per_epoch: 75.0000 - f1_micro: 0.9563 - f1_macro: 0.9562 - f1_weighted: 0.9562 - f1_notweighted: 0.9562
# Epoch 125/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1551 - categorical_accuracy: 0.9530 - val_loss: 0.3527 - val_categorical_accuracy: 0.9591 - 9T_4P: 5.0000 - 4T_9P: 55.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9835 - 2T_Acc: 0.9719 - 3T_Acc: 0.9497 - 4T_Acc: 0.9052 - 5T_Acc: 0.9630 - 6T_Acc: 0.9745 - 7T_Acc: 0.9593 - 8T_Acc: 0.9453 - 9T_Acc: 0.9532 - cm_per_epoch: 75.0000 - f1_micro: 0.9591 - f1_macro: 0.9589 - f1_weighted: 0.9590 - f1_notweighted: 0.9589
# Epoch 126/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1604 - categorical_accuracy: 0.9511 - val_loss: 0.3270 - val_categorical_accuracy: 0.9588 - 9T_4P: 5.0000 - 4T_9P: 54.0000 - 0T_Acc: 0.9819 - 1T_Acc: 0.9812 - 2T_Acc: 0.9707 - 3T_Acc: 0.9510 - 4T_Acc: 0.9079 - 5T_Acc: 0.9615 - 6T_Acc: 0.9745 - 7T_Acc: 0.9541 - 8T_Acc: 0.9480 - 9T_Acc: 0.9558 - cm_per_epoch: 75.0000 - f1_micro: 0.9588 - f1_macro: 0.9586 - f1_weighted: 0.9588 - f1_notweighted: 0.9586
# Epoch 127/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1619 - categorical_accuracy: 0.9512 - val_loss: 0.4589 - val_categorical_accuracy: 0.9587 - 9T_4P: 5.0000 - 4T_9P: 40.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9823 - 2T_Acc: 0.9656 - 3T_Acc: 0.9550 - 4T_Acc: 0.9279 - 5T_Acc: 0.9615 - 6T_Acc: 0.9731 - 7T_Acc: 0.9449 - 8T_Acc: 0.9425 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9587 - f1_macro: 0.9585 - f1_weighted: 0.9587 - f1_notweighted: 0.9585
# Epoch 128/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1485 - categorical_accuracy: 0.9553 - val_loss: 0.3679 - val_categorical_accuracy: 0.9573 - 9T_4P: 5.0000 - 4T_9P: 51.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9859 - 2T_Acc: 0.9668 - 3T_Acc: 0.9536 - 4T_Acc: 0.9132 - 5T_Acc: 0.9571 - 6T_Acc: 0.9674 - 7T_Acc: 0.9436 - 8T_Acc: 0.9425 - 9T_Acc: 0.9558 - cm_per_epoch: 75.0000 - f1_micro: 0.9573 - f1_macro: 0.9572 - f1_weighted: 0.9573 - f1_notweighted: 0.9572
# Epoch 129/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1802 - categorical_accuracy: 0.9474 - val_loss: 0.3375 - val_categorical_accuracy: 0.9580 - 9T_4P: 5.0000 - 4T_9P: 51.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9788 - 2T_Acc: 0.9694 - 3T_Acc: 0.9576 - 4T_Acc: 0.9146 - 5T_Acc: 0.9556 - 6T_Acc: 0.9717 - 7T_Acc: 0.9501 - 8T_Acc: 0.9453 - 9T_Acc: 0.9519 - cm_per_epoch: 75.0000 - f1_micro: 0.9580 - f1_macro: 0.9579 - f1_weighted: 0.9580 - f1_notweighted: 0.9579
# Epoch 130/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1894 - categorical_accuracy: 0.9448 - val_loss: 0.2412 - val_categorical_accuracy: 0.9333 - 9T_4P: 1.0000 - 4T_9P: 142.0000 - 0T_Acc: 0.9819 - 1T_Acc: 0.9823 - 2T_Acc: 0.9528 - 3T_Acc: 0.9642 - 4T_Acc: 0.7997 - 5T_Acc: 0.9246 - 6T_Acc: 0.9575 - 7T_Acc: 0.9580 - 8T_Acc: 0.8317 - 9T_Acc: 0.9714 - cm_per_epoch: 75.0000 - f1_micro: 0.9333 - f1_macro: 0.9337 - f1_weighted: 0.9339 - f1_notweighted: 0.9337
# Epoch 131/140
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1830 - categorical_accuracy: 0.9452 - val_loss: 0.3129 - val_categorical_accuracy: 0.9544 - 9T_4P: 3.0000 - 4T_9P: 88.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9800 - 2T_Acc: 0.9630 - 3T_Acc: 0.9550 - 4T_Acc: 0.8625 - 5T_Acc: 0.9675 - 6T_Acc: 0.9731 - 7T_Acc: 0.9554 - 8T_Acc: 0.9521 - 9T_Acc: 0.9493 - cm_per_epoch: 75.0000 - f1_micro: 0.9544 - f1_macro: 0.9543 - f1_weighted: 0.9544 - f1_notweighted: 0.9543
# Epoch 132/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1744 - categorical_accuracy: 0.9469 - val_loss: 0.3586 - val_categorical_accuracy: 0.9599 - 9T_4P: 5.0000 - 4T_9P: 53.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9870 - 2T_Acc: 0.9681 - 3T_Acc: 0.9616 - 4T_Acc: 0.9025 - 5T_Acc: 0.9630 - 6T_Acc: 0.9759 - 7T_Acc: 0.9541 - 8T_Acc: 0.9480 - 9T_Acc: 0.9519 - cm_per_epoch: 75.0000 - f1_micro: 0.9599 - f1_macro: 0.9597 - f1_weighted: 0.9598 - f1_notweighted: 0.9597
# Epoch 133/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1563 - categorical_accuracy: 0.9510 - val_loss: 0.3953 - val_categorical_accuracy: 0.9599 - 9T_4P: 4.0000 - 4T_9P: 50.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9812 - 2T_Acc: 0.9719 - 3T_Acc: 0.9589 - 4T_Acc: 0.9119 - 5T_Acc: 0.9586 - 6T_Acc: 0.9759 - 7T_Acc: 0.9580 - 8T_Acc: 0.9480 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9599 - f1_macro: 0.9597 - f1_weighted: 0.9598 - f1_notweighted: 0.9597
# Epoch 134/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1576 - categorical_accuracy: 0.9533 - val_loss: 0.4841 - val_categorical_accuracy: 0.9601 - 9T_4P: 8.0000 - 4T_9P: 37.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9823 - 2T_Acc: 0.9617 - 3T_Acc: 0.9576 - 4T_Acc: 0.9306 - 5T_Acc: 0.9615 - 6T_Acc: 0.9759 - 7T_Acc: 0.9606 - 8T_Acc: 0.9398 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9601 - f1_macro: 0.9600 - f1_weighted: 0.9601 - f1_notweighted: 0.9600
# Epoch 135/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1460 - categorical_accuracy: 0.9564 - val_loss: 0.4060 - val_categorical_accuracy: 0.9595 - 9T_4P: 4.0000 - 4T_9P: 42.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9800 - 2T_Acc: 0.9719 - 3T_Acc: 0.9497 - 4T_Acc: 0.9239 - 5T_Acc: 0.9630 - 6T_Acc: 0.9745 - 7T_Acc: 0.9528 - 8T_Acc: 0.9412 - 9T_Acc: 0.9493 - cm_per_epoch: 75.0000 - f1_micro: 0.9595 - f1_macro: 0.9593 - f1_weighted: 0.9594 - f1_notweighted: 0.9593
# Epoch 136/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1613 - categorical_accuracy: 0.9526 - val_loss: 0.1556 - val_categorical_accuracy: 0.9499 - 9T_4P: 0.0000e+00 - 4T_9P: 119.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9812 - 2T_Acc: 0.9630 - 3T_Acc: 0.9457 - 4T_Acc: 0.8198 - 5T_Acc: 0.9645 - 6T_Acc: 0.9589 - 7T_Acc: 0.9633 - 8T_Acc: 0.9508 - 9T_Acc: 0.9623 - cm_per_epoch: 75.0000 - f1_micro: 0.9499 - f1_macro: 0.9497 - f1_weighted: 0.9498 - f1_notweighted: 0.9497
# Epoch 137/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1571 - categorical_accuracy: 0.9518 - val_loss: 0.2793 - val_categorical_accuracy: 0.9577 - 9T_4P: 3.0000 - 4T_9P: 67.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9870 - 2T_Acc: 0.9617 - 3T_Acc: 0.9616 - 4T_Acc: 0.8892 - 5T_Acc: 0.9556 - 6T_Acc: 0.9759 - 7T_Acc: 0.9593 - 8T_Acc: 0.9439 - 9T_Acc: 0.9545 - cm_per_epoch: 75.0000 - f1_micro: 0.9577 - f1_macro: 0.9576 - f1_weighted: 0.9577 - f1_notweighted: 0.9576
# Epoch 138/140
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1471 - categorical_accuracy: 0.9554 - val_loss: 0.4215 - val_categorical_accuracy: 0.9619 - 9T_4P: 5.0000 - 4T_9P: 34.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9835 - 2T_Acc: 0.9707 - 3T_Acc: 0.9603 - 4T_Acc: 0.9346 - 5T_Acc: 0.9630 - 6T_Acc: 0.9759 - 7T_Acc: 0.9488 - 8T_Acc: 0.9494 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9619 - f1_macro: 0.9617 - f1_weighted: 0.9618 - f1_notweighted: 0.9617
# Epoch 139/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1566 - categorical_accuracy: 0.9532 - val_loss: 0.3263 - val_categorical_accuracy: 0.9600 - 9T_4P: 4.0000 - 4T_9P: 46.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9835 - 2T_Acc: 0.9719 - 3T_Acc: 0.9669 - 4T_Acc: 0.9172 - 5T_Acc: 0.9467 - 6T_Acc: 0.9745 - 7T_Acc: 0.9541 - 8T_Acc: 0.9466 - 9T_Acc: 0.9506 - cm_per_epoch: 75.0000 - f1_micro: 0.9600 - f1_macro: 0.9598 - f1_weighted: 0.9600 - f1_notweighted: 0.9598
# Epoch 140/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1483 - categorical_accuracy: 0.9554 - val_loss: 0.3719 - val_categorical_accuracy: 0.9619 - 9T_4P: 3.0000 - 4T_9P: 40.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9823 - 2T_Acc: 0.9719 - 3T_Acc: 0.9629 - 4T_Acc: 0.9266 - 5T_Acc: 0.9586 - 6T_Acc: 0.9773 - 7T_Acc: 0.9475 - 8T_Acc: 0.9508 - 9T_Acc: 0.9519 - cm_per_epoch: 75.0000 - f1_micro: 0.9619 - f1_macro: 0.9617 - f1_weighted: 0.9618 - f1_notweighted: 0.9617
# Epoch 1/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4902 - categorical_accuracy: 0.8637 - val_loss: 0.3103 - val_categorical_accuracy: 0.8939 - 9T_4P: 1.0000 - 4T_9P: 301.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9753 - 2T_Acc: 0.9337 - 3T_Acc: 0.9444 - 4T_Acc: 0.5741 - 5T_Acc: 0.9127 - 6T_Acc: 0.9759 - 7T_Acc: 0.9094 - 8T_Acc: 0.7702 - 9T_Acc: 0.9506 - cm_per_epoch: 75.0000 - f1_micro: 0.8939 - f1_macro: 0.8926 - f1_weighted: 0.8929 - f1_notweighted: 0.8926
# Epoch 2/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3953 - categorical_accuracy: 0.8874 - val_loss: 0.3004 - val_categorical_accuracy: 0.9387 - 9T_4P: 5.0000 - 4T_9P: 90.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9800 - 2T_Acc: 0.9349 - 3T_Acc: 0.9470 - 4T_Acc: 0.8558 - 5T_Acc: 0.9246 - 6T_Acc: 0.9589 - 7T_Acc: 0.9265 - 8T_Acc: 0.9398 - 9T_Acc: 0.9324 - cm_per_epoch: 75.0000 - f1_micro: 0.9387 - f1_macro: 0.9386 - f1_weighted: 0.9387 - f1_notweighted: 0.9386
# Epoch 3/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3874 - categorical_accuracy: 0.8931 - val_loss: 0.2326 - val_categorical_accuracy: 0.9300 - 9T_4P: 1.0000 - 4T_9P: 178.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9812 - 2T_Acc: 0.9477 - 3T_Acc: 0.9444 - 4T_Acc: 0.7316 - 5T_Acc: 0.9423 - 6T_Acc: 0.9575 - 7T_Acc: 0.9213 - 8T_Acc: 0.9412 - 9T_Acc: 0.9454 - cm_per_epoch: 75.0000 - f1_micro: 0.9300 - f1_macro: 0.9296 - f1_weighted: 0.9296 - f1_notweighted: 0.9296
# Epoch 4/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3469 - categorical_accuracy: 0.9018 - val_loss: 0.2620 - val_categorical_accuracy: 0.9371 - 9T_4P: 3.0000 - 4T_9P: 125.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9847 - 2T_Acc: 0.9477 - 3T_Acc: 0.9430 - 4T_Acc: 0.8037 - 5T_Acc: 0.9453 - 6T_Acc: 0.9632 - 7T_Acc: 0.9370 - 8T_Acc: 0.9234 - 9T_Acc: 0.9363 - cm_per_epoch: 75.0000 - f1_micro: 0.9371 - f1_macro: 0.9369 - f1_weighted: 0.9369 - f1_notweighted: 0.9369
# Epoch 5/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3472 - categorical_accuracy: 0.9025 - val_loss: 0.2584 - val_categorical_accuracy: 0.9333 - 9T_4P: 3.0000 - 4T_9P: 137.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9788 - 2T_Acc: 0.9426 - 3T_Acc: 0.9497 - 4T_Acc: 0.7904 - 5T_Acc: 0.9349 - 6T_Acc: 0.9632 - 7T_Acc: 0.9278 - 8T_Acc: 0.9179 - 9T_Acc: 0.9402 - cm_per_epoch: 75.0000 - f1_micro: 0.9333 - f1_macro: 0.9332 - f1_weighted: 0.9332 - f1_notweighted: 0.9332
# Epoch 6/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3238 - categorical_accuracy: 0.9068 - val_loss: 0.2212 - val_categorical_accuracy: 0.9440 - 9T_4P: 2.0000 - 4T_9P: 92.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9812 - 2T_Acc: 0.9541 - 3T_Acc: 0.9417 - 4T_Acc: 0.8518 - 5T_Acc: 0.9497 - 6T_Acc: 0.9561 - 7T_Acc: 0.9344 - 8T_Acc: 0.9412 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9440 - f1_macro: 0.9438 - f1_weighted: 0.9439 - f1_notweighted: 0.9438
# Epoch 7/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3242 - categorical_accuracy: 0.9057 - val_loss: 0.2586 - val_categorical_accuracy: 0.9436 - 9T_4P: 4.0000 - 4T_9P: 84.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9812 - 2T_Acc: 0.9541 - 3T_Acc: 0.9444 - 4T_Acc: 0.8625 - 5T_Acc: 0.9379 - 6T_Acc: 0.9618 - 7T_Acc: 0.9409 - 8T_Acc: 0.9316 - 9T_Acc: 0.9350 - cm_per_epoch: 75.0000 - f1_micro: 0.9436 - f1_macro: 0.9434 - f1_weighted: 0.9435 - f1_notweighted: 0.9434
# Epoch 8/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2998 - categorical_accuracy: 0.9168 - val_loss: 0.2947 - val_categorical_accuracy: 0.9476 - 9T_4P: 8.0000 - 4T_9P: 49.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9847 - 2T_Acc: 0.9439 - 3T_Acc: 0.9351 - 4T_Acc: 0.9065 - 5T_Acc: 0.9467 - 6T_Acc: 0.9589 - 7T_Acc: 0.9331 - 8T_Acc: 0.9521 - 9T_Acc: 0.9298 - cm_per_epoch: 75.0000 - f1_micro: 0.9476 - f1_macro: 0.9474 - f1_weighted: 0.9475 - f1_notweighted: 0.9474
# Epoch 9/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2959 - categorical_accuracy: 0.9155 - val_loss: 0.2250 - val_categorical_accuracy: 0.9348 - 9T_4P: 2.0000 - 4T_9P: 166.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9800 - 2T_Acc: 0.9413 - 3T_Acc: 0.9576 - 4T_Acc: 0.7517 - 5T_Acc: 0.9482 - 6T_Acc: 0.9618 - 7T_Acc: 0.9396 - 8T_Acc: 0.9412 - 9T_Acc: 0.9415 - cm_per_epoch: 75.0000 - f1_micro: 0.9348 - f1_macro: 0.9345 - f1_weighted: 0.9345 - f1_notweighted: 0.9345
# Epoch 10/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3009 - categorical_accuracy: 0.9154 - val_loss: 0.2881 - val_categorical_accuracy: 0.8717 - 9T_4P: 0.0000e+00 - 4T_9P: 647.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9823 - 2T_Acc: 0.9490 - 3T_Acc: 0.9523 - 4T_Acc: 0.1108 - 5T_Acc: 0.9364 - 6T_Acc: 0.9518 - 7T_Acc: 0.9344 - 8T_Acc: 0.9617 - 9T_Acc: 0.9467 - cm_per_epoch: 75.0000 - f1_micro: 0.8717 - f1_macro: 0.8511 - f1_weighted: 0.8507 - f1_notweighted: 0.8511
# Epoch 11/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2912 - categorical_accuracy: 0.9159 - val_loss: 0.2006 - val_categorical_accuracy: 0.9457 - 9T_4P: 2.0000 - 4T_9P: 90.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9788 - 2T_Acc: 0.9592 - 3T_Acc: 0.9404 - 4T_Acc: 0.8571 - 5T_Acc: 0.9408 - 6T_Acc: 0.9632 - 7T_Acc: 0.9449 - 8T_Acc: 0.9330 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9457 - f1_macro: 0.9456 - f1_weighted: 0.9457 - f1_notweighted: 0.9456
# Epoch 12/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2792 - categorical_accuracy: 0.9213 - val_loss: 0.2311 - val_categorical_accuracy: 0.9492 - 9T_4P: 4.0000 - 4T_9P: 58.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9823 - 2T_Acc: 0.9515 - 3T_Acc: 0.9616 - 4T_Acc: 0.9012 - 5T_Acc: 0.9349 - 6T_Acc: 0.9603 - 7T_Acc: 0.9423 - 8T_Acc: 0.9275 - 9T_Acc: 0.9415 - cm_per_epoch: 75.0000 - f1_micro: 0.9492 - f1_macro: 0.9491 - f1_weighted: 0.9492 - f1_notweighted: 0.9491
# Epoch 13/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2854 - categorical_accuracy: 0.9183 - val_loss: 0.2491 - val_categorical_accuracy: 0.9404 - 9T_4P: 5.0000 - 4T_9P: 127.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9835 - 2T_Acc: 0.9554 - 3T_Acc: 0.9589 - 4T_Acc: 0.8051 - 5T_Acc: 0.9393 - 6T_Acc: 0.9688 - 7T_Acc: 0.9383 - 8T_Acc: 0.9316 - 9T_Acc: 0.9350 - cm_per_epoch: 75.0000 - f1_micro: 0.9404 - f1_macro: 0.9402 - f1_weighted: 0.9402 - f1_notweighted: 0.9402
# Epoch 14/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2618 - categorical_accuracy: 0.9233 - val_loss: 0.2837 - val_categorical_accuracy: 0.9507 - 9T_4P: 6.0000 - 4T_9P: 49.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9800 - 2T_Acc: 0.9579 - 3T_Acc: 0.9483 - 4T_Acc: 0.9119 - 5T_Acc: 0.9408 - 6T_Acc: 0.9632 - 7T_Acc: 0.9344 - 8T_Acc: 0.9453 - 9T_Acc: 0.9337 - cm_per_epoch: 75.0000 - f1_micro: 0.9507 - f1_macro: 0.9504 - f1_weighted: 0.9506 - f1_notweighted: 0.9504
# Epoch 15/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2485 - categorical_accuracy: 0.9289 - val_loss: 0.2717 - val_categorical_accuracy: 0.9497 - 9T_4P: 6.0000 - 4T_9P: 60.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9823 - 2T_Acc: 0.9554 - 3T_Acc: 0.9550 - 4T_Acc: 0.9079 - 5T_Acc: 0.9201 - 6T_Acc: 0.9618 - 7T_Acc: 0.9396 - 8T_Acc: 0.9330 - 9T_Acc: 0.9519 - cm_per_epoch: 75.0000 - f1_micro: 0.9497 - f1_macro: 0.9495 - f1_weighted: 0.9497 - f1_notweighted: 0.9495
# Epoch 16/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2604 - categorical_accuracy: 0.9249 - val_loss: 0.2107 - val_categorical_accuracy: 0.9380 - 9T_4P: 2.0000 - 4T_9P: 163.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9741 - 2T_Acc: 0.9592 - 3T_Acc: 0.9430 - 4T_Acc: 0.7650 - 5T_Acc: 0.9527 - 6T_Acc: 0.9745 - 7T_Acc: 0.9396 - 8T_Acc: 0.9261 - 9T_Acc: 0.9571 - cm_per_epoch: 75.0000 - f1_micro: 0.9380 - f1_macro: 0.9381 - f1_weighted: 0.9381 - f1_notweighted: 0.9381
# Epoch 17/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2737 - categorical_accuracy: 0.9216 - val_loss: 0.2527 - val_categorical_accuracy: 0.9324 - 9T_4P: 3.0000 - 4T_9P: 200.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9847 - 2T_Acc: 0.9477 - 3T_Acc: 0.9523 - 4T_Acc: 0.7076 - 5T_Acc: 0.9364 - 6T_Acc: 0.9660 - 7T_Acc: 0.9449 - 8T_Acc: 0.9480 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9324 - f1_macro: 0.9320 - f1_weighted: 0.9320 - f1_notweighted: 0.9320
# Epoch 18/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2833 - categorical_accuracy: 0.9175 - val_loss: 0.2104 - val_categorical_accuracy: 0.9480 - 9T_4P: 3.0000 - 4T_9P: 77.0000 - 0T_Acc: 0.9819 - 1T_Acc: 0.9847 - 2T_Acc: 0.9554 - 3T_Acc: 0.9470 - 4T_Acc: 0.8718 - 5T_Acc: 0.9453 - 6T_Acc: 0.9674 - 7T_Acc: 0.9462 - 8T_Acc: 0.9371 - 9T_Acc: 0.9402 - cm_per_epoch: 75.0000 - f1_micro: 0.9480 - f1_macro: 0.9479 - f1_weighted: 0.9480 - f1_notweighted: 0.9479
# Epoch 19/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2619 - categorical_accuracy: 0.9240 - val_loss: 0.1998 - val_categorical_accuracy: 0.9452 - 9T_4P: 2.0000 - 4T_9P: 111.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9800 - 2T_Acc: 0.9490 - 3T_Acc: 0.9536 - 4T_Acc: 0.8304 - 5T_Acc: 0.9423 - 6T_Acc: 0.9688 - 7T_Acc: 0.9383 - 8T_Acc: 0.9562 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9452 - f1_macro: 0.9451 - f1_weighted: 0.9452 - f1_notweighted: 0.9451
# Epoch 20/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2451 - categorical_accuracy: 0.9281 - val_loss: 0.2035 - val_categorical_accuracy: 0.9503 - 9T_4P: 3.0000 - 4T_9P: 68.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9812 - 2T_Acc: 0.9541 - 3T_Acc: 0.9589 - 4T_Acc: 0.8879 - 5T_Acc: 0.9423 - 6T_Acc: 0.9646 - 7T_Acc: 0.9396 - 8T_Acc: 0.9425 - 9T_Acc: 0.9428 - cm_per_epoch: 75.0000 - f1_micro: 0.9503 - f1_macro: 0.9502 - f1_weighted: 0.9503 - f1_notweighted: 0.9502
# Epoch 21/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2520 - categorical_accuracy: 0.9267 - val_loss: 0.2469 - val_categorical_accuracy: 0.9241 - 9T_4P: 2.0000 - 4T_9P: 274.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9847 - 2T_Acc: 0.9617 - 3T_Acc: 0.9576 - 4T_Acc: 0.6021 - 5T_Acc: 0.9364 - 6T_Acc: 0.9717 - 7T_Acc: 0.9554 - 8T_Acc: 0.9412 - 9T_Acc: 0.9402 - cm_per_epoch: 75.0000 - f1_micro: 0.9241 - f1_macro: 0.9227 - f1_weighted: 0.9226 - f1_notweighted: 0.9227
# Epoch 22/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2648 - categorical_accuracy: 0.9241 - val_loss: 0.2150 - val_categorical_accuracy: 0.9487 - 9T_4P: 3.0000 - 4T_9P: 96.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9835 - 2T_Acc: 0.9566 - 3T_Acc: 0.9444 - 4T_Acc: 0.8465 - 5T_Acc: 0.9541 - 6T_Acc: 0.9703 - 7T_Acc: 0.9488 - 8T_Acc: 0.9466 - 9T_Acc: 0.9493 - cm_per_epoch: 75.0000 - f1_micro: 0.9487 - f1_macro: 0.9485 - f1_weighted: 0.9486 - f1_notweighted: 0.9485
# Epoch 23/140
# 235/235 [==============================] - 2s 9ms/step - loss: 0.2415 - categorical_accuracy: 0.9276 - val_loss: 0.2941 - val_categorical_accuracy: 0.9524 - 9T_4P: 5.0000 - 4T_9P: 60.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9835 - 2T_Acc: 0.9643 - 3T_Acc: 0.9457 - 4T_Acc: 0.9012 - 5T_Acc: 0.9349 - 6T_Acc: 0.9632 - 7T_Acc: 0.9396 - 8T_Acc: 0.9549 - 9T_Acc: 0.9467 - cm_per_epoch: 75.0000 - f1_micro: 0.9524 - f1_macro: 0.9523 - f1_weighted: 0.9524 - f1_notweighted: 0.9523
# Epoch 24/140
# 235/235 [==============================] - 2s 9ms/step - loss: 0.2533 - categorical_accuracy: 0.9271 - val_loss: 0.1957 - val_categorical_accuracy: 0.9485 - 9T_4P: 4.0000 - 4T_9P: 88.0000 - 0T_Acc: 0.9833 - 1T_Acc: 0.9823 - 2T_Acc: 0.9579 - 3T_Acc: 0.9550 - 4T_Acc: 0.8598 - 5T_Acc: 0.9482 - 6T_Acc: 0.9632 - 7T_Acc: 0.9449 - 8T_Acc: 0.9439 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9485 - f1_macro: 0.9485 - f1_weighted: 0.9485 - f1_notweighted: 0.9485
# Epoch 25/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2440 - categorical_accuracy: 0.9302 - val_loss: 0.2366 - val_categorical_accuracy: 0.9547 - 9T_4P: 6.0000 - 4T_9P: 57.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9847 - 2T_Acc: 0.9630 - 3T_Acc: 0.9470 - 4T_Acc: 0.8999 - 5T_Acc: 0.9556 - 6T_Acc: 0.9703 - 7T_Acc: 0.9449 - 8T_Acc: 0.9494 - 9T_Acc: 0.9415 - cm_per_epoch: 75.0000 - f1_micro: 0.9547 - f1_macro: 0.9545 - f1_weighted: 0.9546 - f1_notweighted: 0.9545
# Epoch 26/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2364 - categorical_accuracy: 0.9320 - val_loss: 0.2207 - val_categorical_accuracy: 0.9507 - 9T_4P: 3.0000 - 4T_9P: 76.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9835 - 2T_Acc: 0.9605 - 3T_Acc: 0.9510 - 4T_Acc: 0.8772 - 5T_Acc: 0.9438 - 6T_Acc: 0.9632 - 7T_Acc: 0.9475 - 8T_Acc: 0.9425 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9507 - f1_macro: 0.9505 - f1_weighted: 0.9507 - f1_notweighted: 0.9505
# Epoch 27/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2509 - categorical_accuracy: 0.9284 - val_loss: 0.1767 - val_categorical_accuracy: 0.9471 - 9T_4P: 1.0000 - 4T_9P: 110.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9835 - 2T_Acc: 0.9554 - 3T_Acc: 0.9576 - 4T_Acc: 0.8291 - 5T_Acc: 0.9512 - 6T_Acc: 0.9703 - 7T_Acc: 0.9383 - 8T_Acc: 0.9453 - 9T_Acc: 0.9532 - cm_per_epoch: 75.0000 - f1_micro: 0.9471 - f1_macro: 0.9470 - f1_weighted: 0.9470 - f1_notweighted: 0.9470
# Epoch 28/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2311 - categorical_accuracy: 0.9335 - val_loss: 0.1965 - val_categorical_accuracy: 0.9528 - 9T_4P: 4.0000 - 4T_9P: 69.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9823 - 2T_Acc: 0.9643 - 3T_Acc: 0.9523 - 4T_Acc: 0.8919 - 5T_Acc: 0.9482 - 6T_Acc: 0.9646 - 7T_Acc: 0.9514 - 8T_Acc: 0.9357 - 9T_Acc: 0.9467 - cm_per_epoch: 75.0000 - f1_micro: 0.9528 - f1_macro: 0.9527 - f1_weighted: 0.9528 - f1_notweighted: 0.9527
# Epoch 29/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2346 - categorical_accuracy: 0.9330 - val_loss: 0.2435 - val_categorical_accuracy: 0.9520 - 9T_4P: 6.0000 - 4T_9P: 64.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9823 - 2T_Acc: 0.9643 - 3T_Acc: 0.9470 - 4T_Acc: 0.8959 - 5T_Acc: 0.9349 - 6T_Acc: 0.9703 - 7T_Acc: 0.9423 - 8T_Acc: 0.9535 - 9T_Acc: 0.9376 - cm_per_epoch: 75.0000 - f1_micro: 0.9520 - f1_macro: 0.9519 - f1_weighted: 0.9520 - f1_notweighted: 0.9519
# Epoch 30/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2340 - categorical_accuracy: 0.9334 - val_loss: 0.2109 - val_categorical_accuracy: 0.9196 - 9T_4P: 0.0000e+00 - 4T_9P: 266.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9788 - 2T_Acc: 0.9630 - 3T_Acc: 0.9391 - 4T_Acc: 0.5821 - 5T_Acc: 0.9645 - 6T_Acc: 0.9674 - 7T_Acc: 0.9436 - 8T_Acc: 0.9398 - 9T_Acc: 0.9324 - cm_per_epoch: 75.0000 - f1_micro: 0.9196 - f1_macro: 0.9173 - f1_weighted: 0.9174 - f1_notweighted: 0.9173
# Epoch 31/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2190 - categorical_accuracy: 0.9356 - val_loss: 0.1625 - val_categorical_accuracy: 0.9524 - 9T_4P: 1.0000 - 4T_9P: 75.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9812 - 2T_Acc: 0.9605 - 3T_Acc: 0.9576 - 4T_Acc: 0.8798 - 5T_Acc: 0.9423 - 6T_Acc: 0.9660 - 7T_Acc: 0.9528 - 8T_Acc: 0.9343 - 9T_Acc: 0.9610 - cm_per_epoch: 75.0000 - f1_micro: 0.9524 - f1_macro: 0.9523 - f1_weighted: 0.9524 - f1_notweighted: 0.9523
# Epoch 32/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2236 - categorical_accuracy: 0.9344 - val_loss: 0.1831 - val_categorical_accuracy: 0.9487 - 9T_4P: 3.0000 - 4T_9P: 106.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9835 - 2T_Acc: 0.9605 - 3T_Acc: 0.9523 - 4T_Acc: 0.8385 - 5T_Acc: 0.9601 - 6T_Acc: 0.9688 - 7T_Acc: 0.9541 - 8T_Acc: 0.9330 - 9T_Acc: 0.9467 - cm_per_epoch: 75.0000 - f1_micro: 0.9487 - f1_macro: 0.9486 - f1_weighted: 0.9486 - f1_notweighted: 0.9486
# Epoch 33/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2219 - categorical_accuracy: 0.9339 - val_loss: 0.2546 - val_categorical_accuracy: 0.9556 - 9T_4P: 5.0000 - 4T_9P: 52.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9823 - 2T_Acc: 0.9541 - 3T_Acc: 0.9576 - 4T_Acc: 0.9105 - 5T_Acc: 0.9556 - 6T_Acc: 0.9688 - 7T_Acc: 0.9567 - 8T_Acc: 0.9398 - 9T_Acc: 0.9428 - cm_per_epoch: 75.0000 - f1_micro: 0.9556 - f1_macro: 0.9555 - f1_weighted: 0.9556 - f1_notweighted: 0.9555
# Epoch 34/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2114 - categorical_accuracy: 0.9379 - val_loss: 0.2073 - val_categorical_accuracy: 0.9548 - 9T_4P: 3.0000 - 4T_9P: 57.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9835 - 2T_Acc: 0.9592 - 3T_Acc: 0.9550 - 4T_Acc: 0.9025 - 5T_Acc: 0.9512 - 6T_Acc: 0.9660 - 7T_Acc: 0.9541 - 8T_Acc: 0.9494 - 9T_Acc: 0.9389 - cm_per_epoch: 75.0000 - f1_micro: 0.9548 - f1_macro: 0.9546 - f1_weighted: 0.9547 - f1_notweighted: 0.9546
# Epoch 35/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2198 - categorical_accuracy: 0.9370 - val_loss: 0.2638 - val_categorical_accuracy: 0.9545 - 9T_4P: 6.0000 - 4T_9P: 51.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9823 - 2T_Acc: 0.9541 - 3T_Acc: 0.9589 - 4T_Acc: 0.9132 - 5T_Acc: 0.9453 - 6T_Acc: 0.9660 - 7T_Acc: 0.9541 - 8T_Acc: 0.9412 - 9T_Acc: 0.9389 - cm_per_epoch: 75.0000 - f1_micro: 0.9545 - f1_macro: 0.9544 - f1_weighted: 0.9545 - f1_notweighted: 0.9544
# Epoch 36/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2019 - categorical_accuracy: 0.9400 - val_loss: 0.1905 - val_categorical_accuracy: 0.9556 - 9T_4P: 3.0000 - 4T_9P: 68.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9859 - 2T_Acc: 0.9617 - 3T_Acc: 0.9563 - 4T_Acc: 0.8892 - 5T_Acc: 0.9512 - 6T_Acc: 0.9731 - 7T_Acc: 0.9501 - 8T_Acc: 0.9521 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9556 - f1_macro: 0.9555 - f1_weighted: 0.9556 - f1_notweighted: 0.9555
# Epoch 37/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1979 - categorical_accuracy: 0.9412 - val_loss: 0.2255 - val_categorical_accuracy: 0.9576 - 9T_4P: 4.0000 - 4T_9P: 44.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9835 - 2T_Acc: 0.9656 - 3T_Acc: 0.9351 - 4T_Acc: 0.9226 - 5T_Acc: 0.9556 - 6T_Acc: 0.9731 - 7T_Acc: 0.9528 - 8T_Acc: 0.9521 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9576 - f1_macro: 0.9574 - f1_weighted: 0.9576 - f1_notweighted: 0.9574
# Epoch 38/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2064 - categorical_accuracy: 0.9408 - val_loss: 0.1991 - val_categorical_accuracy: 0.9569 - 9T_4P: 3.0000 - 4T_9P: 59.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9823 - 2T_Acc: 0.9643 - 3T_Acc: 0.9510 - 4T_Acc: 0.9012 - 5T_Acc: 0.9601 - 6T_Acc: 0.9759 - 7T_Acc: 0.9514 - 8T_Acc: 0.9466 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9569 - f1_macro: 0.9568 - f1_weighted: 0.9569 - f1_notweighted: 0.9568
# Epoch 39/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1972 - categorical_accuracy: 0.9438 - val_loss: 0.2136 - val_categorical_accuracy: 0.9561 - 9T_4P: 4.0000 - 4T_9P: 58.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9847 - 2T_Acc: 0.9579 - 3T_Acc: 0.9417 - 4T_Acc: 0.9079 - 5T_Acc: 0.9541 - 6T_Acc: 0.9660 - 7T_Acc: 0.9541 - 8T_Acc: 0.9521 - 9T_Acc: 0.9545 - cm_per_epoch: 75.0000 - f1_micro: 0.9561 - f1_macro: 0.9561 - f1_weighted: 0.9562 - f1_notweighted: 0.9561
# Epoch 40/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1921 - categorical_accuracy: 0.9435 - val_loss: 0.2383 - val_categorical_accuracy: 0.9552 - 9T_4P: 4.0000 - 4T_9P: 71.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9835 - 2T_Acc: 0.9656 - 3T_Acc: 0.9536 - 4T_Acc: 0.8852 - 5T_Acc: 0.9571 - 6T_Acc: 0.9745 - 7T_Acc: 0.9449 - 8T_Acc: 0.9494 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9552 - f1_macro: 0.9552 - f1_weighted: 0.9552 - f1_notweighted: 0.9552
# Epoch 41/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1915 - categorical_accuracy: 0.9430 - val_loss: 0.2144 - val_categorical_accuracy: 0.9589 - 9T_4P: 5.0000 - 4T_9P: 41.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9847 - 2T_Acc: 0.9643 - 3T_Acc: 0.9550 - 4T_Acc: 0.9306 - 5T_Acc: 0.9512 - 6T_Acc: 0.9759 - 7T_Acc: 0.9423 - 8T_Acc: 0.9466 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9589 - f1_macro: 0.9588 - f1_weighted: 0.9589 - f1_notweighted: 0.9588
# Epoch 42/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1862 - categorical_accuracy: 0.9452 - val_loss: 0.2419 - val_categorical_accuracy: 0.9539 - 9T_4P: 5.0000 - 4T_9P: 63.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9835 - 2T_Acc: 0.9605 - 3T_Acc: 0.9563 - 4T_Acc: 0.8959 - 5T_Acc: 0.9497 - 6T_Acc: 0.9703 - 7T_Acc: 0.9462 - 8T_Acc: 0.9466 - 9T_Acc: 0.9402 - cm_per_epoch: 75.0000 - f1_micro: 0.9539 - f1_macro: 0.9538 - f1_weighted: 0.9538 - f1_notweighted: 0.9538
# Epoch 43/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1973 - categorical_accuracy: 0.9423 - val_loss: 0.2479 - val_categorical_accuracy: 0.9565 - 9T_4P: 5.0000 - 4T_9P: 49.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9859 - 2T_Acc: 0.9694 - 3T_Acc: 0.9417 - 4T_Acc: 0.9159 - 5T_Acc: 0.9482 - 6T_Acc: 0.9745 - 7T_Acc: 0.9501 - 8T_Acc: 0.9453 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9565 - f1_macro: 0.9564 - f1_weighted: 0.9565 - f1_notweighted: 0.9564
# Epoch 44/140
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1883 - categorical_accuracy: 0.9443 - val_loss: 0.2242 - val_categorical_accuracy: 0.9557 - 9T_4P: 3.0000 - 4T_9P: 67.0000 - 0T_Acc: 0.9875 - 1T_Acc: 0.9823 - 2T_Acc: 0.9643 - 3T_Acc: 0.9616 - 4T_Acc: 0.8945 - 5T_Acc: 0.9453 - 6T_Acc: 0.9717 - 7T_Acc: 0.9541 - 8T_Acc: 0.9466 - 9T_Acc: 0.9467 - cm_per_epoch: 75.0000 - f1_micro: 0.9557 - f1_macro: 0.9556 - f1_weighted: 0.9557 - f1_notweighted: 0.9556
# Epoch 45/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2009 - categorical_accuracy: 0.9404 - val_loss: 0.2173 - val_categorical_accuracy: 0.9581 - 9T_4P: 3.0000 - 4T_9P: 42.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9847 - 2T_Acc: 0.9630 - 3T_Acc: 0.9404 - 4T_Acc: 0.9292 - 5T_Acc: 0.9512 - 6T_Acc: 0.9731 - 7T_Acc: 0.9528 - 8T_Acc: 0.9494 - 9T_Acc: 0.9493 - cm_per_epoch: 75.0000 - f1_micro: 0.9581 - f1_macro: 0.9579 - f1_weighted: 0.9581 - f1_notweighted: 0.9579
# Epoch 46/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1890 - categorical_accuracy: 0.9439 - val_loss: 0.2570 - val_categorical_accuracy: 0.9601 - 9T_4P: 5.0000 - 4T_9P: 34.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9835 - 2T_Acc: 0.9719 - 3T_Acc: 0.9550 - 4T_Acc: 0.9372 - 5T_Acc: 0.9482 - 6T_Acc: 0.9717 - 7T_Acc: 0.9449 - 8T_Acc: 0.9535 - 9T_Acc: 0.9441 - cm_per_epoch: 75.0000 - f1_micro: 0.9601 - f1_macro: 0.9600 - f1_weighted: 0.9601 - f1_notweighted: 0.9600
# Epoch 47/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1895 - categorical_accuracy: 0.9459 - val_loss: 0.2417 - val_categorical_accuracy: 0.9577 - 9T_4P: 4.0000 - 4T_9P: 60.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9847 - 2T_Acc: 0.9668 - 3T_Acc: 0.9550 - 4T_Acc: 0.9025 - 5T_Acc: 0.9586 - 6T_Acc: 0.9688 - 7T_Acc: 0.9528 - 8T_Acc: 0.9508 - 9T_Acc: 0.9467 - cm_per_epoch: 75.0000 - f1_micro: 0.9577 - f1_macro: 0.9576 - f1_weighted: 0.9577 - f1_notweighted: 0.9576
# Epoch 48/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1904 - categorical_accuracy: 0.9448 - val_loss: 0.1754 - val_categorical_accuracy: 0.9507 - 9T_4P: 2.0000 - 4T_9P: 105.0000 - 0T_Acc: 0.9889 - 1T_Acc: 0.9859 - 2T_Acc: 0.9643 - 3T_Acc: 0.9563 - 4T_Acc: 0.8425 - 5T_Acc: 0.9527 - 6T_Acc: 0.9717 - 7T_Acc: 0.9436 - 8T_Acc: 0.9412 - 9T_Acc: 0.9571 - cm_per_epoch: 75.0000 - f1_micro: 0.9507 - f1_macro: 0.9508 - f1_weighted: 0.9508 - f1_notweighted: 0.9508
# Epoch 49/140
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1883 - categorical_accuracy: 0.9443 - val_loss: 0.2935 - val_categorical_accuracy: 0.9585 - 9T_4P: 5.0000 - 4T_9P: 56.0000 - 0T_Acc: 0.9847 - 1T_Acc: 0.9847 - 2T_Acc: 0.9656 - 3T_Acc: 0.9629 - 4T_Acc: 0.9065 - 5T_Acc: 0.9453 - 6T_Acc: 0.9717 - 7T_Acc: 0.9554 - 8T_Acc: 0.9480 - 9T_Acc: 0.9571 - cm_per_epoch: 75.0000 - f1_micro: 0.9585 - f1_macro: 0.9583 - f1_weighted: 0.9585 - f1_notweighted: 0.9583
# Epoch 50/140
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1952 - categorical_accuracy: 0.9426 - val_loss: 0.2305 - val_categorical_accuracy: 0.9576 - 9T_4P: 3.0000 - 4T_9P: 47.0000 - 0T_Acc: 0.9861 - 1T_Acc: 0.9859 - 2T_Acc: 0.9643 - 3T_Acc: 0.9536 - 4T_Acc: 0.9186 - 5T_Acc: 0.9497 - 6T_Acc: 0.9674 - 7T_Acc: 0.9514 - 8T_Acc: 0.9480 - 9T_Acc: 0.9480 - cm_per_epoch: 75.0000 - f1_micro: 0.9576 - f1_macro: 0.9575 - f1_weighted: 0.9576 - f1_notweighted: 0.9575
# Epoch 51/140
# ...
# Epoch 41/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2698 - categorical_accuracy: 0.1234 - val_loss: 2.2978 - val_categorical_accuracy: 0.1156 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0250 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1156 - f1_macro: 0.0253 - f1_weighted: 0.0278 - f1_notweighted: 0.0253
# Epoch 42/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.2702 - categorical_accuracy: 0.1238 - val_loss: 2.2976 - val_categorical_accuracy: 0.1156 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0250 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1156 - f1_macro: 0.0253 - f1_weighted: 0.0278 - f1_notweighted: 0.0253
# Epoch 43/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2698 - categorical_accuracy: 0.1237 - val_loss: 2.2973 - val_categorical_accuracy: 0.1157 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0264 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1157 - f1_macro: 0.0255 - f1_weighted: 0.0280 - f1_notweighted: 0.0255
# Epoch 44/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.2698 - categorical_accuracy: 0.1242 - val_loss: 2.2969 - val_categorical_accuracy: 0.1160 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0292 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1160 - f1_macro: 0.0261 - f1_weighted: 0.0285 - f1_notweighted: 0.0261
# Epoch 45/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2670 - categorical_accuracy: 0.1248 - val_loss: 2.2965 - val_categorical_accuracy: 0.1161 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0306 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1161 - f1_macro: 0.0263 - f1_weighted: 0.0288 - f1_notweighted: 0.0263
# Epoch 46/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2691 - categorical_accuracy: 0.1250 - val_loss: 2.2964 - val_categorical_accuracy: 0.1165 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0348 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1165 - f1_macro: 0.0271 - f1_weighted: 0.0295 - f1_notweighted: 0.0271
# Epoch 47/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2589 - categorical_accuracy: 0.1257 - val_loss: 2.2953 - val_categorical_accuracy: 0.1168 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0376 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1168 - f1_macro: 0.0276 - f1_weighted: 0.0300 - f1_notweighted: 0.0276
# Epoch 48/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2683 - categorical_accuracy: 0.1252 - val_loss: 2.2944 - val_categorical_accuracy: 0.1177 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0473 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1177 - f1_macro: 0.0295 - f1_weighted: 0.0318 - f1_notweighted: 0.0295
# Epoch 49/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.2555 - categorical_accuracy: 0.1262 - val_loss: 2.2925 - val_categorical_accuracy: 0.1191 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0612 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1191 - f1_macro: 0.0320 - f1_weighted: 0.0342 - f1_notweighted: 0.0320
# Epoch 50/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.2496 - categorical_accuracy: 0.1287 - val_loss: 2.2900 - val_categorical_accuracy: 0.1201 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0723 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1201 - f1_macro: 0.0339 - f1_weighted: 0.0361 - f1_notweighted: 0.0339
# Epoch 51/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.2598 - categorical_accuracy: 0.1298 - val_loss: 2.2831 - val_categorical_accuracy: 0.1224 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0960 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1224 - f1_macro: 0.0379 - f1_weighted: 0.0399 - f1_notweighted: 0.0379
# Epoch 52/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.2345 - categorical_accuracy: 0.1364 - val_loss: 2.2714 - val_categorical_accuracy: 0.1271 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.1307 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0132 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1271 - f1_macro: 0.0445 - f1_weighted: 0.0464 - f1_notweighted: 0.0445
# Epoch 53/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.2263 - categorical_accuracy: 0.1401 - val_loss: 2.2668 - val_categorical_accuracy: 0.1319 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.1446 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0477 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1319 - f1_macro: 0.0527 - f1_weighted: 0.0546 - f1_notweighted: 0.0527
# Epoch 54/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2237 - categorical_accuracy: 0.1426 - val_loss: 2.2638 - val_categorical_accuracy: 0.1333 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.1613 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0464 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1333 - f1_macro: 0.0550 - f1_weighted: 0.0568 - f1_notweighted: 0.0550
# Epoch 55/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.2179 - categorical_accuracy: 0.1446 - val_loss: 2.2388 - val_categorical_accuracy: 0.1512 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.2017 - 1T_Acc: 0.9988 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.1868 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1512 - f1_macro: 0.0759 - f1_weighted: 0.0779 - f1_notweighted: 0.0759
# Epoch 56/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.2050 - categorical_accuracy: 0.1511 - val_loss: 2.2275 - val_categorical_accuracy: 0.1589 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.2350 - 1T_Acc: 0.9965 - 2T_Acc: 0.2258 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1589 - f1_macro: 0.0834 - f1_weighted: 0.0863 - f1_notweighted: 0.0834
# Epoch 57/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1981 - categorical_accuracy: 0.1537 - val_loss: 2.2230 - val_categorical_accuracy: 0.1455 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.3185 - 1T_Acc: 1.0000 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0172 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1455 - f1_macro: 0.0635 - f1_weighted: 0.0648 - f1_notweighted: 0.0635
# Epoch 58/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1665 - categorical_accuracy: 0.1672 - val_loss: 2.1941 - val_categorical_accuracy: 0.1492 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.3950 - 1T_Acc: 0.0024 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0914 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0028 - 7T_Acc: 1.0000 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1492 - f1_macro: 0.0837 - f1_weighted: 0.0822 - f1_notweighted: 0.0837
# Epoch 59/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1529 - categorical_accuracy: 0.1751 - val_loss: 2.2097 - val_categorical_accuracy: 0.1240 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0320 - 1T_Acc: 0.0259 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.1820 - 6T_Acc: 0.0000e+00 - 7T_Acc: 1.0000 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1240 - f1_macro: 0.0508 - f1_weighted: 0.0496 - f1_notweighted: 0.0508
# Epoch 60/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.1410 - categorical_accuracy: 0.1818 - val_loss: 2.1738 - val_categorical_accuracy: 0.1575 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.5605 - 1T_Acc: 0.0000e+00 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0207 - 6T_Acc: 0.0028 - 7T_Acc: 1.0000 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1575 - f1_macro: 0.0918 - f1_weighted: 0.0889 - f1_notweighted: 0.0918
# Epoch 61/140
# 235/235 [==============================] - 2s 10ms/step - loss: 2.1095 - categorical_accuracy: 0.1892 - val_loss: 2.0345 - val_categorical_accuracy: 0.2108 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.7497 - 1T_Acc: 0.0047 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.3563 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0099 - 7T_Acc: 1.0000 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.2108 - f1_macro: 0.1197 - f1_weighted: 0.1181 - f1_notweighted: 0.1197
# Epoch 62/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0932 - categorical_accuracy: 0.1962 - val_loss: 2.1115 - val_categorical_accuracy: 0.1775 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.7747 - 1T_Acc: 0.0000e+00 - 2T_Acc: 0.0140 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0028 - 7T_Acc: 0.9987 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1775 - f1_macro: 0.1068 - f1_weighted: 0.1037 - f1_notweighted: 0.1068
# Epoch 63/140
# 235/235 [==============================] - 2s 8ms/step - loss: 2.0633 - categorical_accuracy: 0.2085 - val_loss: 2.0571 - val_categorical_accuracy: 0.1433 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.0167 - 1T_Acc: 0.0000e+00 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.4482 - 6T_Acc: 0.0028 - 7T_Acc: 0.9948 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1433 - f1_macro: 0.0495 - f1_weighted: 0.0478 - f1_notweighted: 0.0495
# Epoch 64/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0577 - categorical_accuracy: 0.2076 - val_loss: 2.0095 - val_categorical_accuracy: 0.1795 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.3644 - 1T_Acc: 0.0012 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.4734 - 6T_Acc: 0.0028 - 7T_Acc: 0.9948 - 8T_Acc: 0.0041 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1795 - f1_macro: 0.1033 - f1_weighted: 0.0994 - f1_notweighted: 0.1033
# Epoch 65/140
# 235/235 [==============================] - 2s 8ms/step - loss: 3.6530 - categorical_accuracy: 0.1722 - val_loss: 2.2986 - val_categorical_accuracy: 0.1197 - 9T_4P: 0.0000e+00 - 4T_9P: 749.0000 - 0T_Acc: 0.1794 - 1T_Acc: 0.0000e+00 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0000e+00 - 8T_Acc: 0.0000e+00 - 9T_Acc: 1.0000 - cm_per_epoch: 75.0000 - f1_micro: 0.1197 - f1_macro: 0.0492 - f1_weighted: 0.0484 - f1_notweighted: 0.0492
# Epoch 66/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.1384 - categorical_accuracy: 0.1770 - val_loss: 2.1251 - val_categorical_accuracy: 0.1763 - 9T_4P: 0.0000e+00 - 4T_9P: 749.0000 - 0T_Acc: 0.7677 - 1T_Acc: 0.0000e+00 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0015 - 6T_Acc: 0.0000e+00 - 7T_Acc: 0.0013 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.9987 - cm_per_epoch: 75.0000 - f1_micro: 0.1763 - f1_macro: 0.1055 - f1_weighted: 0.1025 - f1_notweighted: 0.1055
# Epoch 67/140
# 235/235 [==============================] - 2s 9ms/step - loss: 2.0707 - categorical_accuracy: 0.2049 - val_loss: 2.0824 - val_categorical_accuracy: 0.1856 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.8734 - 1T_Acc: 0.0000e+00 - 2T_Acc: 0.0000e+00 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0028 - 7T_Acc: 1.0000 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.1856 - f1_macro: 0.1104 - f1_weighted: 0.1070 - f1_notweighted: 0.1104
# Epoch 68/140
# 235/235 [==============================] - 2s 9ms/step - loss: 1.9456 - categorical_accuracy: 0.2548 - val_loss: 1.8662 - val_categorical_accuracy: 0.2931 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.9124 - 1T_Acc: 0.0094 - 2T_Acc: 0.7500 - 3T_Acc: 0.0000e+00 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.2175 - 6T_Acc: 0.0652 - 7T_Acc: 0.9882 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.2931 - f1_macro: 0.2082 - f1_weighted: 0.2034 - f1_notweighted: 0.2082
# Epoch 69/140
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9680 - categorical_accuracy: 0.2475 - val_loss: 1.9017 - val_categorical_accuracy: 0.2075 - 9T_4P: 0.0000e+00 - 4T_9P: 1.0000 - 0T_Acc: 0.9458 - 1T_Acc: 0.0318 - 2T_Acc: 0.0013 - 3T_Acc: 0.0728 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.0000e+00 - 6T_Acc: 0.0113 - 7T_Acc: 0.9856 - 8T_Acc: 0.0465 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.2075 - f1_macro: 0.0981 - f1_weighted: 0.0974 - f1_notweighted: 0.0981
# Epoch 70/140
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9095 - categorical_accuracy: 0.2627 - val_loss: 1.8440 - val_categorical_accuracy: 0.2375 - 9T_4P: 0.0000e+00 - 4T_9P: 0.0000e+00 - 0T_Acc: 0.9263 - 1T_Acc: 0.0094 - 2T_Acc: 0.0013 - 3T_Acc: 0.0305 - 4T_Acc: 0.0000e+00 - 5T_Acc: 0.1731 - 6T_Acc: 0.3088 - 7T_Acc: 0.9816 - 8T_Acc: 0.0000e+00 - 9T_Acc: 0.0000e+00 - cm_per_epoch: 75.0000 - f1_micro: 0.2375 - f1_macro: 0.1542 - f1_weighted: 0.1489 - f1_notweighted: 0.1542
# Epoch 71/140
# 221/235 [===========================>..] - ETA: 0s - loss: 4.2865 - categorical_accuracy: 0.2184

# %% [markdown]
# #### Download the multiple runs and reps of Model History from training with different lambda values
#
#
# Also commented out because once everything is ran and saved, I don't want to accidentally save additional files

# %%
# Download the history
from google.colab import files


#  SUPER IMPORTANT ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
for item in model_history_all:
  # item.history
  del item.model
# IF YOU DON'T DELETE THE MODEL YOU WON'T BE ABLE TO UNPICKLE YOUR RESULTS AND THAT WILL SUCK AND YOU WILL CRY
# and no ones wants to see you ugly cry over hours of wasted coding


import pickle

# create a variable
#model_history_all #50 items
#cm_all #50 items

# save the variable to a pickle file
with open('initial_10_secondphase_lambda_history.pkl', 'wb') as f:
    pickle.dump(model_history_all, f)

files.download('initial_10_secondphase_lambda_history.pkl')

with open('initial_10_secondphase_lambda_cm.pkl', 'wb') as f:
    pickle.dump(cm_all, f)

files.download('initial_10_secondphase_lambda_cm.pkl')

# %% [markdown]
# #### Load Model History Variables from Pickle Files - must have weighted-categorical-accuracy defined

# %%
# #Upload and save the history to variable 
# import pickle

# # #load the pickle file
# with open('initial_1_secondphase_lambda_history.pkl', 'rb') as handle:
#     model_history_all = pickle.load(handle)

# # import keras
# # keras.models.load_model('initial_10_secondphase_lambda_history.pkl')
# #use the loaded variable
# print(model_history_all)

# # #load the pickle file
# # with open('initial_10_secondphase_lambda_cm.pkl', 'rb') as handle:
# #     cm_all = pickle.load(handle)

# #use the loaded variable
# # print(cm_all)

# %% [markdown]
# #### Example of how to concatenate multiple dataframes without causing an error.  Have to use pandas concatenate function.

# %%
#@title
import pandas as pd

# Create an empty dataframe
df = pd.DataFrame()

# Create a list of data
data = [1, 2, 3, 4, 5]

# Use a for loop to fill the dataframe
for x in data:
    df = pd.concat([df, pd.DataFrame({'Number':[x], 'Square':[x**2]})], ignore_index=True)

# Show the dataframe
print(df)

# %% [markdown]
# #### Loading the data into a Dataframe to be saved as a CSV file

# %%
#I want to break out the model_history and cm_history into a dataframe to be referenced by Cost and Rep
import pandas as pd
df = pd.DataFrame()
count=1


#It'd be better if i could refer to the "cost"/lambda2 as a variable in the model_history, 
# but i recreated it here

cost_list = [10, 100, 1000, 1] # Each one takes about 2 minutes 5*4*2=40 minutes for 5 costs/4 reps -- actually all took 40 reps took almost  1.5 hours

# cost_list = [ 10]

for k in cost_list:

  
#It'd be better if i could refer to the reps a variable in the model_history, 
# but i recreated it here as the range(10) that was originally used

  for i in range(1):
    # print("k: ", k, "i: ", i)
    df = pd.concat([df, pd.DataFrame({"cost": [k], "rep": [i],
                                      "model_history": [model_history_all[count-1]],
                                      # "cm": [cm_all[count-1]]
                                      })] , 
                   ignore_index=True )
    count+=1    


# I create a dataframe with CSV but  don't save/download it 
df.to_csv('dataframe.csv',index=False)

# %%
#I want to add the 50 epochs i did of lambda1 = 1 using SGD to this list

df = pd.concat([df, pd.DataFrame({"cost": 1, "rep": 1,
                                      "model_history": [model_history],
                                      # "cm": [cm_all[count-1]]
                                      })] , 
                   ignore_index=True )

# %% [markdown]
# ##### Example of using df.groupby in a for loop to plot multiple types of data - doesn't include Label
# ```
# for group in df.groupby("cost"):
#   fig = plt.figure(figsize=(20, 10))
#   fig, ax = plt.subplots(1,2)
#   ax[0].scatter(group[1]["cost"], group[1]["quantity"])
#   ax[0].set_title("cost vs. quantity")
#   ax[1].scatter(group[1]["cost"], group[1]["revenue"])
#   ax[1].set_title("cost vs. revenue")
#   plt.show()
#
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import time
nb_epoch = 50
patience = 0
df.groupby("cost")

for x, group in df.groupby("cost"):
  fig = plt.figure(figsize=(20, 10)) # I don't think this works for some reason
  fig, ax = plt.subplots(1,2)
  print("Group of Lambda-Value:",   x)

  # group
  for item in group.model_history:
    plot_model_history_all(item)    
  plt.show()
    # for item, cm3 in zip(group.model_history, group.cm):

  #   # cm3_wodiag = cm3*(np.ones((10,10)) - np.eye(10))

  #   # ax[2] = sns.heatmap(cm3_wodiag, annot=True, annot_kws={"size": 7},  fmt='g', cmap=sns.cm.rocket_r, cbar=False) # font size
  #   # ax[2].set_xlabel('Predicted Class')
  #   # ax[2].set_ylabel('True Class')
  #   # ax[2].set_title('# of misclassifications of 9 as 4 is '+str(cm3[4][9]))
  #   # cbar = ax[2].collections[0].colorbar
  #   # cbar.remove() # Just takes up valuable room and is worthless
  #   plot_model_history_all(item)    

  #   #   ax[0].set_title("Lambda Value of"+str(df["cost"]))
    
  # #   # print(0+r,' to ', r+4+1)  #Correct
